# %% [markdown]
# ## 1.Dataset Modules

# %%
def read_transactions_file(file_path):
    # Open the file in read mode
    with open(file_path, 'r') as file:
        # Initialize an empty dictionary to store the transaction data
        transactions_data = {}

        # Read the file line by line
        for line in file:
            # Split each line into its components
            components = line.strip().split(':')

            # Extract the relevant attributes/features
            user_id = components[0]
            transaction_id = components[1]
            description = components[2]
            amount = float(components[3])
            x_coordinate = float(components[4])
            y_coordinate = float(components[5])
            is_fraudulent = bool(components[6])

            # Create a dictionary with the extracted data and add it to the transactions_data dictionary
            transaction_data = {'user_id': user_id, 'transaction_id': transaction_id, 'description': description,
                                'amount': amount, 'x_coordinate': x_coordinate, 'y_coordinate': y_coordinate,
                                'is_fraudulent': is_fraudulent}
            transactions_data[transaction_id] = transaction_data

    # Return the dictionary with the transaction data
    return transactions_data

# %%
transactions_data = read_transactions_file('datasets/Transaction.txt')
transactions_data
# Out:
# {'500000': {'user_id': '21',
#   'transaction_id': '500000',
#   'description': 'HMS HOST-BOS AIRPT',
#   'amount': 36.55,
#   'x_coordinate': 884.0,
#   'y_coordinate': 755.0,
#   'is_fraudulent': True},
#  '500001': {'user_id': '21',
#   'transaction_id': '500001',
#   'description': 'H & M',
#   'amount': 72.85,
#   'x_coordinate': 727.0,
#   'y_coordinate': 827.0,
#   'is_fraudulent': True},
#  '500002': {'user_id': '21',
#   'transaction_id': '500002',
#   'description': 'VERIZON WEB',
#   'amount': 61.17,
#   'x_coordinate': 926.0,
#   'y_coordinate': 841.0,
#   'is_fraudulent': True},
#  '500003': {'user_id': '21',
#   'transaction_id': '500003',
#   'description': "MARIO'S ITALIAN RSTR",
#   'amount': 47.02,
#   'x_coordinate': 860.0,
#   'y_coordinate': 886.0,
#   'is_fraudulent': True},
#  '500004': {'user_id': '21',
#   'transaction_id': '500004',
#   'description': 'LORD & TAYLOR',
#   'amount': 10.12,
#   'x_coordinate': 910.0,
#   'y_coordinate': 949.0,
#   'is_fraudulent': True},
#  '500005': {'user_id': '21',
#   'transaction_id': '500005',
#   'description': 'SUPERCUTS',
#   'amount': 66.29,
#   'x_coordinate': 988.0,
#   'y_coordinate': 782.0,
#   'is_fraudulent': True},
#  '500006': {'user_id': '21',
#   'transaction_id': '500006',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 47.05,
#   'x_coordinate': 801.0,
#   'y_coordinate': 732.0,
#   'is_fraudulent': True},
#  '500007': {'user_id': '21',
#   'transaction_id': '500007',
#   'description': 'EXPRESS',
#   'amount': 63.96,
#   'x_coordinate': 973.0,
#   'y_coordinate': 903.0,
#   'is_fraudulent': True},
#  '500008': {'user_id': '21',
#   'transaction_id': '500008',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 72.47,
#   'x_coordinate': 867.0,
#   'y_coordinate': 787.0,
#   'is_fraudulent': True},
#  '500009': {'user_id': '21',
#   'transaction_id': '500009',
#   'description': 'STAPLES',
#   'amount': 66.92,
#   'x_coordinate': 838.0,
#   'y_coordinate': 990.0,
#   'is_fraudulent': True},
#  '500010': {'user_id': '21',
#   'transaction_id': '500010',
#   'description': 'SURF STYLE',
#   'amount': 52.49,
#   'x_coordinate': 733.0,
#   'y_coordinate': 775.0,
#   'is_fraudulent': True},
#  '500011': {'user_id': '21',
#   'transaction_id': '500011',
#   'description': 'BENTLEY COLLEGE',
#   'amount': 19.65,
#   'x_coordinate': 804.0,
#   'y_coordinate': 803.0,
#   'is_fraudulent': True},
#  '500012': {'user_id': '21',
#   'transaction_id': '500012',
#   'description': 'FAST LANE',
#   'amount': 79.02,
#   'x_coordinate': 940.0,
#   'y_coordinate': 709.0,
#   'is_fraudulent': True},
#  '500013': {'user_id': '21',
#   'transaction_id': '500013',
#   'description': 'EXPEDIA TRAVEL',
#   'amount': 54.8,
#   'x_coordinate': 711.0,
#   'y_coordinate': 838.0,
#   'is_fraudulent': True},
#  '500014': {'user_id': '21',
#   'transaction_id': '500014',
#   'description': 'GREEN PAPAYA',
#   'amount': 62.28,
#   'x_coordinate': 847.0,
#   'y_coordinate': 824.0,
#   'is_fraudulent': True},
#  '500015': {'user_id': '21',
#   'transaction_id': '500015',
#   'description': 'INDIA CAFE',
#   'amount': 16.29,
#   'x_coordinate': 972.0,
#   'y_coordinate': 819.0,
#   'is_fraudulent': True},
#  '500016': {'user_id': '21',
#   'transaction_id': '500016',
#   'description': "L'ESPLANADE",
#   'amount': 35.48,
#   'x_coordinate': 747.0,
#   'y_coordinate': 743.0,
#   'is_fraudulent': True},
#  '500017': {'user_id': '21',
#   'transaction_id': '500017',
#   'description': 'SUPERCUTS',
#   'amount': 35.13,
#   'x_coordinate': 764.0,
#   'y_coordinate': 832.0,
#   'is_fraudulent': True},
#  '500018': {'user_id': '21',
#   'transaction_id': '500018',
#   'description': 'COPLEY DARTMOUTH GARAG',
#   'amount': 61.73,
#   'x_coordinate': 814.0,
#   'y_coordinate': 920.0,
#   'is_fraudulent': True},
#  '500019': {'user_id': '21',
#   'transaction_id': '500019',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 75.45,
#   'x_coordinate': 754.0,
#   'y_coordinate': 903.0,
#   'is_fraudulent': True},
#  '500020': {'user_id': '21',
#   'transaction_id': '500020',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 48.95,
#   'x_coordinate': 744.0,
#   'y_coordinate': 973.0,
#   'is_fraudulent': True},
#  '500021': {'user_id': '21',
#   'transaction_id': '500021',
#   'description': 'BORDERS BOOKS',
#   'amount': 45.51,
#   'x_coordinate': 941.0,
#   'y_coordinate': 742.0,
#   'is_fraudulent': True},
#  '500022': {'user_id': '21',
#   'transaction_id': '500022',
#   'description': 'COPLEY DARTMOUTH GARAG',
#   'amount': 50.89,
#   'x_coordinate': 891.0,
#   'y_coordinate': 744.0,
#   'is_fraudulent': True},
#  '500023': {'user_id': '21',
#   'transaction_id': '500023',
#   'description': 'MGH YAWKEY PRKNG GARAG',
#   'amount': 85.35,
#   'x_coordinate': 910.0,
#   'y_coordinate': 770.0,
#   'is_fraudulent': True},
#  '500024': {'user_id': '21',
#   'transaction_id': '500024',
#   'description': 'STAPLES',
#   'amount': 38.28,
#   'x_coordinate': 916.0,
#   'y_coordinate': 895.0,
#   'is_fraudulent': True},
#  '500025': {'user_id': '21',
#   'transaction_id': '500025',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 50.47,
#   'x_coordinate': 980.0,
#   'y_coordinate': 996.0,
#   'is_fraudulent': True},
#  '500026': {'user_id': '21',
#   'transaction_id': '500026',
#   'description': 'WAL-MART',
#   'amount': 46.74,
#   'x_coordinate': 880.0,
#   'y_coordinate': 713.0,
#   'is_fraudulent': True},
#  '500027': {'user_id': '21',
#   'transaction_id': '500027',
#   'description': 'EXPRESS',
#   'amount': 63.34,
#   'x_coordinate': 826.0,
#   'y_coordinate': 842.0,
#   'is_fraudulent': True},
#  '500028': {'user_id': '21',
#   'transaction_id': '500028',
#   'description': 'EXPRESS',
#   'amount': 36.57,
#   'x_coordinate': 735.0,
#   'y_coordinate': 744.0,
#   'is_fraudulent': True},
#  '500029': {'user_id': '21',
#   'transaction_id': '500029',
#   'description': 'JULIOS LIQUORS',
#   'amount': 37.14,
#   'x_coordinate': 729.0,
#   'y_coordinate': 741.0,
#   'is_fraudulent': True},
#  '500030': {'user_id': '21',
#   'transaction_id': '500030',
#   'description': "MACY'S EAST",
#   'amount': 33.02,
#   'x_coordinate': 882.0,
#   'y_coordinate': 953.0,
#   'is_fraudulent': True},
#  '500031': {'user_id': '21',
#   'transaction_id': '500031',
#   'description': 'MGH YAWKEY PRKNG GARAG',
#   'amount': 27.01,
#   'x_coordinate': 989.0,
#   'y_coordinate': 781.0,
#   'is_fraudulent': True},
#  '500032': {'user_id': '21',
#   'transaction_id': '500032',
#   'description': 'STAPLES',
#   'amount': 21.86,
#   'x_coordinate': 744.0,
#   'y_coordinate': 818.0,
#   'is_fraudulent': True},
#  '500033': {'user_id': '21',
#   'transaction_id': '500033',
#   'description': 'BENTLEY COLLEGE',
#   'amount': 59.5,
#   'x_coordinate': 849.0,
#   'y_coordinate': 818.0,
#   'is_fraudulent': True},
#  '500034': {'user_id': '21',
#   'transaction_id': '500034',
#   'description': '48HOURPRINT.COM',
#   'amount': 48.22,
#   'x_coordinate': 986.0,
#   'y_coordinate': 951.0,
#   'is_fraudulent': True},
#  '500035': {'user_id': '21',
#   'transaction_id': '500035',
#   'description': "JERRY'S FAMOUS DELI",
#   'amount': 39.12,
#   'x_coordinate': 778.0,
#   'y_coordinate': 963.0,
#   'is_fraudulent': True},
#  '500036': {'user_id': '21',
#   'transaction_id': '500036',
#   'description': 'MELT GELATO & CREPE',
#   'amount': 63.43,
#   'x_coordinate': 946.0,
#   'y_coordinate': 821.0,
#   'is_fraudulent': True},
#  '500037': {'user_id': '21',
#   'transaction_id': '500037',
#   'description': 'COPLEY DARTMOUTH GARAG',
#   'amount': 63.4,
#   'x_coordinate': 818.0,
#   'y_coordinate': 725.0,
#   'is_fraudulent': True},
#  '500038': {'user_id': '21',
#   'transaction_id': '500038',
#   'description': "L'ESPLANADE",
#   'amount': 62.22,
#   'x_coordinate': 709.0,
#   'y_coordinate': 979.0,
#   'is_fraudulent': True},
#  '500039': {'user_id': '21',
#   'transaction_id': '500039',
#   'description': 'CVS PHARMACY',
#   'amount': 15.51,
#   'x_coordinate': 832.0,
#   'y_coordinate': 952.0,
#   'is_fraudulent': True},
#  '500040': {'user_id': '21',
#   'transaction_id': '500040',
#   'description': 'CVS PHARMACY',
#   'amount': 56.2,
#   'x_coordinate': 874.0,
#   'y_coordinate': 790.0,
#   'is_fraudulent': True},
#  '500041': {'user_id': '21',
#   'transaction_id': '500041',
#   'description': 'GULF OIL',
#   'amount': 63.87,
#   'x_coordinate': 852.0,
#   'y_coordinate': 935.0,
#   'is_fraudulent': True},
#  '500042': {'user_id': '21',
#   'transaction_id': '500042',
#   'description': 'SUPERCUTS',
#   'amount': 3.43,
#   'x_coordinate': 928.0,
#   'y_coordinate': 927.0,
#   'is_fraudulent': True},
#  '500043': {'user_id': '21',
#   'transaction_id': '500043',
#   'description': 'MASSPORT AUTH LOGAN PK',
#   'amount': 19.31,
#   'x_coordinate': 808.0,
#   'y_coordinate': 806.0,
#   'is_fraudulent': True},
#  '500044': {'user_id': '21',
#   'transaction_id': '500044',
#   'description': "MARIO'S ITALIAN RSTR",
#   'amount': 88.93,
#   'x_coordinate': 968.0,
#   'y_coordinate': 883.0,
#   'is_fraudulent': True},
#  '500045': {'user_id': '21',
#   'transaction_id': '500045',
#   'description': 'RANCHO ARGENTINO',
#   'amount': 99.34,
#   'x_coordinate': 798.0,
#   'y_coordinate': 859.0,
#   'is_fraudulent': True},
#  '500046': {'user_id': '21',
#   'transaction_id': '500046',
#   'description': 'PEETS COFFEE/TEA',
#   'amount': 65.35,
#   'x_coordinate': 758.0,
#   'y_coordinate': 826.0,
#   'is_fraudulent': True},
#  '500047': {'user_id': '21',
#   'transaction_id': '500047',
#   'description': 'BORDERS BOOKS',
#   'amount': 78.44,
#   'x_coordinate': 867.0,
#   'y_coordinate': 703.0,
#   'is_fraudulent': True},
#  '500048': {'user_id': '21',
#   'transaction_id': '500048',
#   'description': 'INDIA CAFE',
#   'amount': 55.44,
#   'x_coordinate': 899.0,
#   'y_coordinate': 713.0,
#   'is_fraudulent': True},
#  '500049': {'user_id': '21',
#   'transaction_id': '500049',
#   'description': 'EXPEDIA TRAVEL',
#   'amount': 82.74,
#   'x_coordinate': 719.0,
#   'y_coordinate': 871.0,
#   'is_fraudulent': True},
#  '500050': {'user_id': '21',
#   'transaction_id': '500050',
#   'description': 'MELT GELATO & CREPE',
#   'amount': 78.46,
#   'x_coordinate': 974.0,
#   'y_coordinate': 832.0,
#   'is_fraudulent': True},
#  '500051': {'user_id': '21',
#   'transaction_id': '500051',
#   'description': 'RANCHO ARGENTINO',
#   'amount': 24.93,
#   'x_coordinate': 851.0,
#   'y_coordinate': 865.0,
#   'is_fraudulent': True},
#  '500052': {'user_id': '21',
#   'transaction_id': '500052',
#   'description': 'STARBUCKS USA',
#   'amount': 66.19,
#   'x_coordinate': 892.0,
#   'y_coordinate': 870.0,
#   'is_fraudulent': True},
#  '500053': {'user_id': '21',
#   'transaction_id': '500053',
#   'description': 'MARSHALLS',
#   'amount': 81.76,
#   'x_coordinate': 983.0,
#   'y_coordinate': 841.0,
#   'is_fraudulent': True},
#  '500054': {'user_id': '21',
#   'transaction_id': '500054',
#   'description': 'BORDERS BOOKS',
#   'amount': 27.89,
#   'x_coordinate': 957.0,
#   'y_coordinate': 925.0,
#   'is_fraudulent': True},
#  '500055': {'user_id': '21',
#   'transaction_id': '500055',
#   'description': "MARIO'S ITALIAN RSTR",
#   'amount': 42.31,
#   'x_coordinate': 896.0,
#   'y_coordinate': 899.0,
#   'is_fraudulent': True},
#  '500056': {'user_id': '21',
#   'transaction_id': '500056',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 55.17,
#   'x_coordinate': 800.0,
#   'y_coordinate': 849.0,
#   'is_fraudulent': True},
#  '500057': {'user_id': '21',
#   'transaction_id': '500057',
#   'description': 'BARNES & NOBLE',
#   'amount': 64.39,
#   'x_coordinate': 841.0,
#   'y_coordinate': 784.0,
#   'is_fraudulent': True},
#  '500058': {'user_id': '21',
#   'transaction_id': '500058',
#   'description': 'SURF STYLE',
#   'amount': 92.56,
#   'x_coordinate': 921.0,
#   'y_coordinate': 735.0,
#   'is_fraudulent': True},
#  '500059': {'user_id': '21',
#   'transaction_id': '500059',
#   'description': 'LEGAL SEA FOODS',
#   'amount': 43.6,
#   'x_coordinate': 826.0,
#   'y_coordinate': 824.0,
#   'is_fraudulent': True},
#  '500060': {'user_id': '21',
#   'transaction_id': '500060',
#   'description': 'STARBUCKS USA',
#   'amount': 24.83,
#   'x_coordinate': 993.0,
#   'y_coordinate': 838.0,
#   'is_fraudulent': True},
#  '500061': {'user_id': '21',
#   'transaction_id': '500061',
#   'description': 'MARSHALLS',
#   'amount': 49.35,
#   'x_coordinate': 744.0,
#   'y_coordinate': 937.0,
#   'is_fraudulent': True},
#  '500062': {'user_id': '21',
#   'transaction_id': '500062',
#   'description': 'CIRCUIT CITY',
#   'amount': 75.66,
#   'x_coordinate': 973.0,
#   'y_coordinate': 843.0,
#   'is_fraudulent': True},
#  '500063': {'user_id': '21',
#   'transaction_id': '500063',
#   'description': 'PEPPERONI EXPRESS',
#   'amount': 62.61,
#   'x_coordinate': 750.0,
#   'y_coordinate': 839.0,
#   'is_fraudulent': True},
#  '500064': {'user_id': '21',
#   'transaction_id': '500064',
#   'description': 'RANCHO ARGENTINO',
#   'amount': 61.79,
#   'x_coordinate': 839.0,
#   'y_coordinate': 875.0,
#   'is_fraudulent': True},
#  '500065': {'user_id': '21',
#   'transaction_id': '500065',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 70.95,
#   'x_coordinate': 972.0,
#   'y_coordinate': 864.0,
#   'is_fraudulent': True},
#  '500066': {'user_id': '21',
#   'transaction_id': '500066',
#   'description': 'LEGAL SEA FOODS',
#   'amount': 38.85,
#   'x_coordinate': 840.0,
#   'y_coordinate': 732.0,
#   'is_fraudulent': True},
#  '500067': {'user_id': '21',
#   'transaction_id': '500067',
#   'description': 'HMS HOST-BOS AIRPT',
#   'amount': 42.8,
#   'x_coordinate': 812.0,
#   'y_coordinate': 742.0,
#   'is_fraudulent': True},
#  '500068': {'user_id': '21',
#   'transaction_id': '500068',
#   'description': 'BORDERS BOOKS',
#   'amount': 43.61,
#   'x_coordinate': 824.0,
#   'y_coordinate': 750.0,
#   'is_fraudulent': True},
#  '500069': {'user_id': '21',
#   'transaction_id': '500069',
#   'description': 'OUTBACK',
#   'amount': 81.84,
#   'x_coordinate': 899.0,
#   'y_coordinate': 932.0,
#   'is_fraudulent': True},
#  '500070': {'user_id': '21',
#   'transaction_id': '500070',
#   'description': 'MASSPORT AUTH LOGAN PK',
#   'amount': 13.13,
#   'x_coordinate': 737.0,
#   'y_coordinate': 821.0,
#   'is_fraudulent': True},
#  '500071': {'user_id': '21',
#   'transaction_id': '500071',
#   'description': 'EXPRESS',
#   'amount': 66.7,
#   'x_coordinate': 945.0,
#   'y_coordinate': 784.0,
#   'is_fraudulent': True},
#  '500072': {'user_id': '21',
#   'transaction_id': '500072',
#   'description': 'HMS HOST-BOS AIRPT',
#   'amount': 67.51,
#   'x_coordinate': 838.0,
#   'y_coordinate': 770.0,
#   'is_fraudulent': True},
#  '500073': {'user_id': '21',
#   'transaction_id': '500073',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 50.68,
#   'x_coordinate': 992.0,
#   'y_coordinate': 843.0,
#   'is_fraudulent': True},
#  '500074': {'user_id': '21',
#   'transaction_id': '500074',
#   'description': 'AMERCN SCTY FOR INFO S',
#   'amount': 50.62,
#   'x_coordinate': 732.0,
#   'y_coordinate': 861.0,
#   'is_fraudulent': True},
#  '500075': {'user_id': '21',
#   'transaction_id': '500075',
#   'description': "TRADER JOE'S",
#   'amount': 7.88,
#   'x_coordinate': 841.0,
#   'y_coordinate': 907.0,
#   'is_fraudulent': True},
#  '500076': {'user_id': '21',
#   'transaction_id': '500076',
#   'description': 'PANERA BREAD',
#   'amount': 35.24,
#   'x_coordinate': 863.0,
#   'y_coordinate': 761.0,
#   'is_fraudulent': True},
#  '500077': {'user_id': '21',
#   'transaction_id': '500077',
#   'description': 'MASSPORT AUTH LOGAN PK',
#   'amount': 31.88,
#   'x_coordinate': 899.0,
#   'y_coordinate': 832.0,
#   'is_fraudulent': True},
#  '500078': {'user_id': '21',
#   'transaction_id': '500078',
#   'description': 'WHOLEFDS FRA 10156 SWH',
#   'amount': 46.51,
#   'x_coordinate': 843.0,
#   'y_coordinate': 700.0,
#   'is_fraudulent': True},
#  '500079': {'user_id': '21',
#   'transaction_id': '500079',
#   'description': 'PEETS COFFEE/TEA',
#   'amount': 30.64,
#   'x_coordinate': 911.0,
#   'y_coordinate': 955.0,
#   'is_fraudulent': True},
#  '500080': {'user_id': '21',
#   'transaction_id': '500080',
#   'description': 'TOM CAN COOK',
#   'amount': 30.25,
#   'x_coordinate': 963.0,
#   'y_coordinate': 907.0,
#   'is_fraudulent': True},
#  '500081': {'user_id': '21',
#   'transaction_id': '500081',
#   'description': 'BARNES & NOBLE',
#   'amount': 84.08,
#   'x_coordinate': 747.0,
#   'y_coordinate': 971.0,
#   'is_fraudulent': True},
#  '500082': {'user_id': '21',
#   'transaction_id': '500082',
#   'description': 'WAL-MART',
#   'amount': 66.42,
#   'x_coordinate': 853.0,
#   'y_coordinate': 996.0,
#   'is_fraudulent': True},
#  '500083': {'user_id': '21',
#   'transaction_id': '500083',
#   'description': 'MARSHALLS',
#   'amount': 41.97,
#   'x_coordinate': 868.0,
#   'y_coordinate': 832.0,
#   'is_fraudulent': True},
#  '500084': {'user_id': '21',
#   'transaction_id': '500084',
#   'description': 'JULIOS LIQUORS',
#   'amount': 46.92,
#   'x_coordinate': 821.0,
#   'y_coordinate': 821.0,
#   'is_fraudulent': True},
#  '500085': {'user_id': '21',
#   'transaction_id': '500085',
#   'description': 'TOM CAN COOK',
#   'amount': 73.39,
#   'x_coordinate': 842.0,
#   'y_coordinate': 990.0,
#   'is_fraudulent': True},
#  '500086': {'user_id': '21',
#   'transaction_id': '500086',
#   'description': 'BARNES & NOBLE',
#   'amount': 54.69,
#   'x_coordinate': 777.0,
#   'y_coordinate': 962.0,
#   'is_fraudulent': True},
#  '500087': {'user_id': '21',
#   'transaction_id': '500087',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 46.82,
#   'x_coordinate': 766.0,
#   'y_coordinate': 878.0,
#   'is_fraudulent': True},
#  '500088': {'user_id': '21',
#   'transaction_id': '500088',
#   'description': 'CIRCUIT CITY',
#   'amount': 29.23,
#   'x_coordinate': 891.0,
#   'y_coordinate': 709.0,
#   'is_fraudulent': True},
#  '500089': {'user_id': '21',
#   'transaction_id': '500089',
#   'description': 'GULF OIL',
#   'amount': 73.7,
#   'x_coordinate': 956.0,
#   'y_coordinate': 906.0,
#   'is_fraudulent': True},
#  '500090': {'user_id': '21',
#   'transaction_id': '500090',
#   'description': 'WHOLEFDS FRA 10156 SWH',
#   'amount': 67.76,
#   'x_coordinate': 704.0,
#   'y_coordinate': 772.0,
#   'is_fraudulent': True},
#  '500091': {'user_id': '21',
#   'transaction_id': '500091',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 33.29,
#   'x_coordinate': 987.0,
#   'y_coordinate': 858.0,
#   'is_fraudulent': True},
#  '500092': {'user_id': '21',
#   'transaction_id': '500092',
#   'description': 'EXPEDIA TRAVEL',
#   'amount': 40.29,
#   'x_coordinate': 879.0,
#   'y_coordinate': 783.0,
#   'is_fraudulent': True},
#  '500093': {'user_id': '21',
#   'transaction_id': '500093',
#   'description': 'WHOLEFDS WOB 10233 SWH',
#   'amount': 29.3,
#   'x_coordinate': 995.0,
#   'y_coordinate': 853.0,
#   'is_fraudulent': True},
#  '500094': {'user_id': '21',
#   'transaction_id': '500094',
#   'description': 'STOP & SHOP',
#   'amount': 45.82,
#   'x_coordinate': 863.0,
#   'y_coordinate': 972.0,
#   'is_fraudulent': True},
#  '500095': {'user_id': '21',
#   'transaction_id': '500095',
#   'description': 'GREEN PAPAYA',
#   'amount': 48.93,
#   'x_coordinate': 771.0,
#   'y_coordinate': 843.0,
#   'is_fraudulent': True},
#  '500096': {'user_id': '21',
#   'transaction_id': '500096',
#   'description': 'BENTLEY COLLEGE',
#   'amount': 82.72,
#   'x_coordinate': 831.0,
#   'y_coordinate': 705.0,
#   'is_fraudulent': True},
#  '500097': {'user_id': '21',
#   'transaction_id': '500097',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 68.81,
#   'x_coordinate': 918.0,
#   'y_coordinate': 700.0,
#   'is_fraudulent': True},
#  '500098': {'user_id': '21',
#   'transaction_id': '500098',
#   'description': "MACY'S EAST",
#   'amount': 31.03,
#   'x_coordinate': 983.0,
#   'y_coordinate': 931.0,
#   'is_fraudulent': True},
#  '500099': {'user_id': '21',
#   'transaction_id': '500099',
#   'description': 'AU BON PAIN',
#   'amount': 43.51,
#   'x_coordinate': 867.0,
#   'y_coordinate': 895.0,
#   'is_fraudulent': True},
#  '500100': {'user_id': '21',
#   'transaction_id': '500100',
#   'description': 'HOTEL PLEASURE',
#   'amount': 4042.34,
#   'x_coordinate': 189.0,
#   'y_coordinate': 81.0,
#   'is_fraudulent': True},
#  '500101': {'user_id': '21',
#   'transaction_id': '500101',
#   'description': 'CAFE QWERTY',
#   'amount': 3949.97,
#   'x_coordinate': 68.0,
#   'y_coordinate': 154.0,
#   'is_fraudulent': True},
#  '500102': {'user_id': '21',
#   'transaction_id': '500102',
#   'description': 'whole flash',
#   'amount': 4134.79,
#   'x_coordinate': 191.0,
#   'y_coordinate': 96.0,
#   'is_fraudulent': True},
#  '500103': {'user_id': '21',
#   'transaction_id': '500103',
#   'description': 'AMAZON.TW',
#   'amount': 4038.09,
#   'x_coordinate': 163.0,
#   'y_coordinate': 131.0,
#   'is_fraudulent': True},
#  '500104': {'user_id': '21',
#   'transaction_id': '500104',
#   'description': 'USAIRWAY',
#   'amount': 3874.92,
#   'x_coordinate': 173.0,
#   'y_coordinate': 51.0,
#   'is_fraudulent': True},
#  '500105': {'user_id': '21',
#   'transaction_id': '500105',
#   'description': 'HOTEL PLEASURE',
#   'amount': 3976.08,
#   'x_coordinate': 133.0,
#   'y_coordinate': 191.0,
#   'is_fraudulent': True},
#  '500106': {'user_id': '21',
#   'transaction_id': '500106',
#   'description': 'coffee YYY',
#   'amount': 3855.62,
#   'x_coordinate': 91.0,
#   'y_coordinate': 127.0,
#   'is_fraudulent': True},
#  '500107': {'user_id': '21',
#   'transaction_id': '500107',
#   'description': 'CANADIAN PHARMACY',
#   'amount': 4070.97,
#   'x_coordinate': 144.0,
#   'y_coordinate': 126.0,
#   'is_fraudulent': True},
#  '500108': {'user_id': '21',
#   'transaction_id': '500108',
#   'description': 'CIKUIT CITY',
#   'amount': 3937.79,
#   'x_coordinate': 184.0,
#   'y_coordinate': 57.0,
#   'is_fraudulent': True},
#  '500109': {'user_id': '21',
#   'transaction_id': '500109',
#   'description': 'CAFE QWERTY',
#   'amount': 3914.93,
#   'x_coordinate': 199.0,
#   'y_coordinate': 121.0,
#   'is_fraudulent': True},
#  '500110': {'user_id': '22',
#   'transaction_id': '500110',
#   'description': 'THE GINGER PAD',
#   'amount': 19.21,
#   'x_coordinate': 811.0,
#   'y_coordinate': 939.0,
#   'is_fraudulent': True},
#  '500111': {'user_id': '22',
#   'transaction_id': '500111',
#   'description': "MACY'S EAST",
#   'amount': 20.54,
#   'x_coordinate': 847.0,
#   'y_coordinate': 833.0,
#   'is_fraudulent': True},
#  '500112': {'user_id': '22',
#   'transaction_id': '500112',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 4.69,
#   'x_coordinate': 827.0,
#   'y_coordinate': 845.0,
#   'is_fraudulent': True},
#  '500113': {'user_id': '22',
#   'transaction_id': '500113',
#   'description': 'INDIA CAFE',
#   'amount': 37.81,
#   'x_coordinate': 774.0,
#   'y_coordinate': 967.0,
#   'is_fraudulent': True},
#  '500114': {'user_id': '22',
#   'transaction_id': '500114',
#   'description': 'JULIOS LIQUORS',
#   'amount': 68.61,
#   'x_coordinate': 828.0,
#   'y_coordinate': 780.0,
#   'is_fraudulent': True},
#  '500115': {'user_id': '22',
#   'transaction_id': '500115',
#   'description': 'INDIA CAFE',
#   'amount': 14.83,
#   'x_coordinate': 881.0,
#   'y_coordinate': 911.0,
#   'is_fraudulent': True},
#  '500116': {'user_id': '22',
#   'transaction_id': '500116',
#   'description': 'THE HOME DEPOT',
#   'amount': 85.83,
#   'x_coordinate': 748.0,
#   'y_coordinate': 875.0,
#   'is_fraudulent': True},
#  '500117': {'user_id': '22',
#   'transaction_id': '500117',
#   'description': 'GULF OIL',
#   'amount': 52.82,
#   'x_coordinate': 787.0,
#   'y_coordinate': 997.0,
#   'is_fraudulent': True},
#  '500118': {'user_id': '22',
#   'transaction_id': '500118',
#   'description': 'WHOLEFDS WOB 10233 SWH',
#   'amount': 34.39,
#   'x_coordinate': 878.0,
#   'y_coordinate': 866.0,
#   'is_fraudulent': True},
#  '500119': {'user_id': '22',
#   'transaction_id': '500119',
#   'description': 'AU BON PAIN',
#   'amount': 52.6,
#   'x_coordinate': 908.0,
#   'y_coordinate': 883.0,
#   'is_fraudulent': True},
#  '500120': {'user_id': '22',
#   'transaction_id': '500120',
#   'description': 'HYATT HOTELS MIAMI F&B',
#   'amount': 56.38,
#   'x_coordinate': 853.0,
#   'y_coordinate': 719.0,
#   'is_fraudulent': True},
#  '500121': {'user_id': '22',
#   'transaction_id': '500121',
#   'description': 'USAIRWAY',
#   'amount': 34.19,
#   'x_coordinate': 859.0,
#   'y_coordinate': 864.0,
#   'is_fraudulent': True},
#  '500122': {'user_id': '22',
#   'transaction_id': '500122',
#   'description': 'COPLEY DARTMOUTH GARAG',
#   'amount': 84.42,
#   'x_coordinate': 885.0,
#   'y_coordinate': 811.0,
#   'is_fraudulent': True},
#  '500123': {'user_id': '22',
#   'transaction_id': '500123',
#   'description': "TRADER JOE'S",
#   'amount': 66.69,
#   'x_coordinate': 915.0,
#   'y_coordinate': 743.0,
#   'is_fraudulent': True},
#  '500124': {'user_id': '22',
#   'transaction_id': '500124',
#   'description': "L'ESPLANADE",
#   'amount': 52.9,
#   'x_coordinate': 754.0,
#   'y_coordinate': 982.0,
#   'is_fraudulent': True},
#  '500125': {'user_id': '22',
#   'transaction_id': '500125',
#   'description': 'THE HOME DEPOT',
#   'amount': 33.66,
#   'x_coordinate': 770.0,
#   'y_coordinate': 703.0,
#   'is_fraudulent': True},
#  '500126': {'user_id': '22',
#   'transaction_id': '500126',
#   'description': 'AMAZON.COM',
#   'amount': 67.31,
#   'x_coordinate': 814.0,
#   'y_coordinate': 756.0,
#   'is_fraudulent': True},
#  '500127': {'user_id': '22',
#   'transaction_id': '500127',
#   'description': 'WAL-MART',
#   'amount': 15.85,
#   'x_coordinate': 978.0,
#   'y_coordinate': 915.0,
#   'is_fraudulent': True},
#  '500128': {'user_id': '22',
#   'transaction_id': '500128',
#   'description': 'H & M',
#   'amount': 93.34,
#   'x_coordinate': 742.0,
#   'y_coordinate': 777.0,
#   'is_fraudulent': True},
#  '500129': {'user_id': '22',
#   'transaction_id': '500129',
#   'description': 'INDIA CAFE',
#   'amount': 43.73,
#   'x_coordinate': 839.0,
#   'y_coordinate': 867.0,
#   'is_fraudulent': True},
#  '500130': {'user_id': '22',
#   'transaction_id': '500130',
#   'description': 'COPLEY DARTMOUTH GARAG',
#   'amount': 31.05,
#   'x_coordinate': 957.0,
#   'y_coordinate': 752.0,
#   'is_fraudulent': True},
#  '500131': {'user_id': '22',
#   'transaction_id': '500131',
#   'description': 'EXPEDIA TRAVEL',
#   'amount': 65.39,
#   'x_coordinate': 937.0,
#   'y_coordinate': 707.0,
#   'is_fraudulent': True},
#  '500132': {'user_id': '22',
#   'transaction_id': '500132',
#   'description': 'COPLEY DARTMOUTH GARAG',
#   'amount': 58.32,
#   'x_coordinate': 737.0,
#   'y_coordinate': 730.0,
#   'is_fraudulent': True},
#  '500133': {'user_id': '22',
#   'transaction_id': '500133',
#   'description': 'MELT GELATO & CREPE',
#   'amount': 44.31,
#   'x_coordinate': 867.0,
#   'y_coordinate': 861.0,
#   'is_fraudulent': True},
#  '500134': {'user_id': '22',
#   'transaction_id': '500134',
#   'description': 'EXPEDIA TRAVEL',
#   'amount': 69.79,
#   'x_coordinate': 865.0,
#   'y_coordinate': 957.0,
#   'is_fraudulent': True},
#  '500135': {'user_id': '22',
#   'transaction_id': '500135',
#   'description': 'HMS HOST-BOS AIRPT',
#   'amount': 29.18,
#   'x_coordinate': 880.0,
#   'y_coordinate': 885.0,
#   'is_fraudulent': True},
#  '500136': {'user_id': '22',
#   'transaction_id': '500136',
#   'description': 'HYATT HOTELS MIAMI F&B',
#   'amount': 33.52,
#   'x_coordinate': 929.0,
#   'y_coordinate': 758.0,
#   'is_fraudulent': True},
#  '500137': {'user_id': '22',
#   'transaction_id': '500137',
#   'description': 'STAPLES',
#   'amount': 48.19,
#   'x_coordinate': 789.0,
#   'y_coordinate': 906.0,
#   'is_fraudulent': True},
#  '500138': {'user_id': '22',
#   'transaction_id': '500138',
#   'description': 'COPLEY DARTMOUTH GARAG',
#   'amount': 56.44,
#   'x_coordinate': 723.0,
#   'y_coordinate': 935.0,
#   'is_fraudulent': True},
#  '500139': {'user_id': '22',
#   'transaction_id': '500139',
#   'description': 'PEPPERONI EXPRESS',
#   'amount': 34.62,
#   'x_coordinate': 980.0,
#   'y_coordinate': 759.0,
#   'is_fraudulent': True},
#  '500140': {'user_id': '22',
#   'transaction_id': '500140',
#   'description': 'SATO RESTAURANT',
#   'amount': 59.4,
#   'x_coordinate': 727.0,
#   'y_coordinate': 957.0,
#   'is_fraudulent': True},
#  '500141': {'user_id': '22',
#   'transaction_id': '500141',
#   'description': 'SUPERCUTS',
#   'amount': 59.55,
#   'x_coordinate': 769.0,
#   'y_coordinate': 930.0,
#   'is_fraudulent': True},
#  '500142': {'user_id': '22',
#   'transaction_id': '500142',
#   'description': 'STAPLES',
#   'amount': 35.29,
#   'x_coordinate': 952.0,
#   'y_coordinate': 939.0,
#   'is_fraudulent': True},
#  '500143': {'user_id': '22',
#   'transaction_id': '500143',
#   'description': 'PANERA BREAD',
#   'amount': 34.02,
#   'x_coordinate': 760.0,
#   'y_coordinate': 974.0,
#   'is_fraudulent': True},
#  '500144': {'user_id': '22',
#   'transaction_id': '500144',
#   'description': 'GULF OIL',
#   'amount': 37.79,
#   'x_coordinate': 951.0,
#   'y_coordinate': 813.0,
#   'is_fraudulent': True},
#  '500145': {'user_id': '22',
#   'transaction_id': '500145',
#   'description': 'THE GINGER PAD',
#   'amount': 48.05,
#   'x_coordinate': 758.0,
#   'y_coordinate': 735.0,
#   'is_fraudulent': True},
#  '500146': {'user_id': '22',
#   'transaction_id': '500146',
#   'description': 'REDBOX DVD',
#   'amount': 29.83,
#   'x_coordinate': 943.0,
#   'y_coordinate': 949.0,
#   'is_fraudulent': True},
#  '500147': {'user_id': '22',
#   'transaction_id': '500147',
#   'description': "MACY'S EAST",
#   'amount': 44.25,
#   'x_coordinate': 787.0,
#   'y_coordinate': 842.0,
#   'is_fraudulent': True},
#  '500148': {'user_id': '22',
#   'transaction_id': '500148',
#   'description': 'REDBOX DVD',
#   'amount': 48.0,
#   'x_coordinate': 840.0,
#   'y_coordinate': 925.0,
#   'is_fraudulent': True},
#  '500149': {'user_id': '22',
#   'transaction_id': '500149',
#   'description': 'REDBOX DVD',
#   'amount': 65.35,
#   'x_coordinate': 776.0,
#   'y_coordinate': 847.0,
#   'is_fraudulent': True},
#  '500150': {'user_id': '22',
#   'transaction_id': '500150',
#   'description': 'SUNOCO SVC STATION',
#   'amount': 41.96,
#   'x_coordinate': 852.0,
#   'y_coordinate': 938.0,
#   'is_fraudulent': True},
#  '500151': {'user_id': '22',
#   'transaction_id': '500151',
#   'description': 'OUTBACK',
#   'amount': 27.3,
#   'x_coordinate': 954.0,
#   'y_coordinate': 937.0,
#   'is_fraudulent': True},
#  '500152': {'user_id': '22',
#   'transaction_id': '500152',
#   'description': 'MGH YAWKEY PRKNG GARAG',
#   'amount': 31.65,
#   'x_coordinate': 838.0,
#   'y_coordinate': 744.0,
#   'is_fraudulent': True},
#  '500153': {'user_id': '22',
#   'transaction_id': '500153',
#   'description': "MACY'S EAST",
#   'amount': 54.91,
#   'x_coordinate': 731.0,
#   'y_coordinate': 974.0,
#   'is_fraudulent': True},
#  '500154': {'user_id': '22',
#   'transaction_id': '500154',
#   'description': 'BARNES & NOBLE',
#   'amount': 51.92,
#   'x_coordinate': 722.0,
#   'y_coordinate': 766.0,
#   'is_fraudulent': True},
#  '500155': {'user_id': '22',
#   'transaction_id': '500155',
#   'description': "MARIO'S ITALIAN RSTR",
#   'amount': 37.79,
#   'x_coordinate': 986.0,
#   'y_coordinate': 815.0,
#   'is_fraudulent': True},
#  '500156': {'user_id': '22',
#   'transaction_id': '500156',
#   'description': 'INDIA CAFE',
#   'amount': 73.98,
#   'x_coordinate': 814.0,
#   'y_coordinate': 910.0,
#   'is_fraudulent': True},
#  '500157': {'user_id': '22',
#   'transaction_id': '500157',
#   'description': 'SATO RESTAURANT',
#   'amount': 12.52,
#   'x_coordinate': 990.0,
#   'y_coordinate': 714.0,
#   'is_fraudulent': True},
#  '500158': {'user_id': '22',
#   'transaction_id': '500158',
#   'description': 'AMERCN SCTY FOR INFO S',
#   'amount': 59.56,
#   'x_coordinate': 942.0,
#   'y_coordinate': 726.0,
#   'is_fraudulent': True},
#  '500159': {'user_id': '22',
#   'transaction_id': '500159',
#   'description': 'BENTLEY COLLEGE',
#   'amount': 33.97,
#   'x_coordinate': 833.0,
#   'y_coordinate': 756.0,
#   'is_fraudulent': True},
#  '500160': {'user_id': '22',
#   'transaction_id': '500160',
#   'description': "REBECCA'S CAFE",
#   'amount': 82.97,
#   'x_coordinate': 887.0,
#   'y_coordinate': 834.0,
#   'is_fraudulent': True},
#  '500161': {'user_id': '22',
#   'transaction_id': '500161',
#   'description': 'OUTBACK',
#   'amount': 50.16,
#   'x_coordinate': 885.0,
#   'y_coordinate': 921.0,
#   'is_fraudulent': True},
#  '500162': {'user_id': '22',
#   'transaction_id': '500162',
#   'description': 'EXXONMOBIL',
#   'amount': 71.4,
#   'x_coordinate': 900.0,
#   'y_coordinate': 915.0,
#   'is_fraudulent': True},
#  '500163': {'user_id': '22',
#   'transaction_id': '500163',
#   'description': "TRADER JOE'S",
#   'amount': 72.78,
#   'x_coordinate': 833.0,
#   'y_coordinate': 737.0,
#   'is_fraudulent': True},
#  '500164': {'user_id': '22',
#   'transaction_id': '500164',
#   'description': 'AMERCN SCTY FOR INFO S',
#   'amount': 35.73,
#   'x_coordinate': 842.0,
#   'y_coordinate': 961.0,
#   'is_fraudulent': True},
#  '500165': {'user_id': '22',
#   'transaction_id': '500165',
#   'description': 'OUTBACK',
#   'amount': 72.11,
#   'x_coordinate': 930.0,
#   'y_coordinate': 876.0,
#   'is_fraudulent': True},
#  '500166': {'user_id': '22',
#   'transaction_id': '500166',
#   'description': '48HOURPRINT.COM',
#   'amount': 41.76,
#   'x_coordinate': 946.0,
#   'y_coordinate': 951.0,
#   'is_fraudulent': True},
#  '500167': {'user_id': '22',
#   'transaction_id': '500167',
#   'description': 'AMERCN SCTY FOR INFO S',
#   'amount': 50.31,
#   'x_coordinate': 714.0,
#   'y_coordinate': 709.0,
#   'is_fraudulent': True},
#  '500168': {'user_id': '22',
#   'transaction_id': '500168',
#   'description': 'PANERA BREAD',
#   'amount': 67.71,
#   'x_coordinate': 876.0,
#   'y_coordinate': 798.0,
#   'is_fraudulent': True},
#  '500169': {'user_id': '22',
#   'transaction_id': '500169',
#   'description': "REBECCA'S CAFE",
#   'amount': 14.51,
#   'x_coordinate': 910.0,
#   'y_coordinate': 986.0,
#   'is_fraudulent': True},
#  '500170': {'user_id': '22',
#   'transaction_id': '500170',
#   'description': 'THE HOME DEPOT',
#   'amount': 54.18,
#   'x_coordinate': 825.0,
#   'y_coordinate': 968.0,
#   'is_fraudulent': True},
#  '500171': {'user_id': '22',
#   'transaction_id': '500171',
#   'description': 'PEETS COFFEE/TEA',
#   'amount': 38.64,
#   'x_coordinate': 849.0,
#   'y_coordinate': 703.0,
#   'is_fraudulent': True},
#  '500172': {'user_id': '22',
#   'transaction_id': '500172',
#   'description': 'WHOLEFDS FRA 10156 SWH',
#   'amount': 38.65,
#   'x_coordinate': 710.0,
#   'y_coordinate': 831.0,
#   'is_fraudulent': True},
#  '500173': {'user_id': '22',
#   'transaction_id': '500173',
#   'description': 'JULIOS LIQUORS',
#   'amount': 41.78,
#   'x_coordinate': 977.0,
#   'y_coordinate': 900.0,
#   'is_fraudulent': True},
#  '500174': {'user_id': '22',
#   'transaction_id': '500174',
#   'description': 'CIRCUIT CITY',
#   'amount': 8.21,
#   'x_coordinate': 760.0,
#   'y_coordinate': 991.0,
#   'is_fraudulent': True},
#  '500175': {'user_id': '22',
#   'transaction_id': '500175',
#   'description': 'STOP & SHOP',
#   'amount': 34.09,
#   'x_coordinate': 839.0,
#   'y_coordinate': 718.0,
#   'is_fraudulent': True},
#  '500176': {'user_id': '22',
#   'transaction_id': '500176',
#   'description': "TRADER JOE'S",
#   'amount': 48.65,
#   'x_coordinate': 799.0,
#   'y_coordinate': 705.0,
#   'is_fraudulent': True},
#  '500177': {'user_id': '22',
#   'transaction_id': '500177',
#   'description': 'BARNES & NOBLE',
#   'amount': 14.35,
#   'x_coordinate': 887.0,
#   'y_coordinate': 989.0,
#   'is_fraudulent': True},
#  '500178': {'user_id': '22',
#   'transaction_id': '500178',
#   'description': 'CVS PHARMACY',
#   'amount': 69.14,
#   'x_coordinate': 949.0,
#   'y_coordinate': 882.0,
#   'is_fraudulent': True},
#  '500179': {'user_id': '22',
#   'transaction_id': '500179',
#   'description': 'STARBUCKS USA',
#   'amount': 43.52,
#   'x_coordinate': 921.0,
#   'y_coordinate': 733.0,
#   'is_fraudulent': True},
#  '500180': {'user_id': '22',
#   'transaction_id': '500180',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 37.74,
#   'x_coordinate': 898.0,
#   'y_coordinate': 933.0,
#   'is_fraudulent': True},
#  '500181': {'user_id': '22',
#   'transaction_id': '500181',
#   'description': 'THE GINGER PAD',
#   'amount': 45.29,
#   'x_coordinate': 911.0,
#   'y_coordinate': 702.0,
#   'is_fraudulent': True},
#  '500182': {'user_id': '22',
#   'transaction_id': '500182',
#   'description': 'GREEN PAPAYA',
#   'amount': 71.08,
#   'x_coordinate': 839.0,
#   'y_coordinate': 754.0,
#   'is_fraudulent': True},
#  '500183': {'user_id': '22',
#   'transaction_id': '500183',
#   'description': 'VERIZON WEB',
#   'amount': 62.65,
#   'x_coordinate': 884.0,
#   'y_coordinate': 866.0,
#   'is_fraudulent': True},
#  '500184': {'user_id': '22',
#   'transaction_id': '500184',
#   'description': 'AU BON PAIN',
#   'amount': 80.09,
#   'x_coordinate': 866.0,
#   'y_coordinate': 932.0,
#   'is_fraudulent': True},
#  '500185': {'user_id': '22',
#   'transaction_id': '500185',
#   'description': 'COPLEY DARTMOUTH GARAG',
#   'amount': 72.32,
#   'x_coordinate': 915.0,
#   'y_coordinate': 911.0,
#   'is_fraudulent': True},
#  '500186': {'user_id': '22',
#   'transaction_id': '500186',
#   'description': 'HMS HOST-BOS AIRPT',
#   'amount': 35.2,
#   'x_coordinate': 961.0,
#   'y_coordinate': 925.0,
#   'is_fraudulent': True},
#  '500187': {'user_id': '22',
#   'transaction_id': '500187',
#   'description': 'EXPRESS',
#   'amount': 70.15,
#   'x_coordinate': 720.0,
#   'y_coordinate': 946.0,
#   'is_fraudulent': True},
#  '500188': {'user_id': '22',
#   'transaction_id': '500188',
#   'description': 'THE GINGER PAD',
#   'amount': 75.27,
#   'x_coordinate': 945.0,
#   'y_coordinate': 868.0,
#   'is_fraudulent': True},
#  '500189': {'user_id': '22',
#   'transaction_id': '500189',
#   'description': 'VERIZON WEB',
#   'amount': 77.13,
#   'x_coordinate': 989.0,
#   'y_coordinate': 949.0,
#   'is_fraudulent': True},
#  '500190': {'user_id': '22',
#   'transaction_id': '500190',
#   'description': 'CIRCUIT CITY',
#   'amount': 47.78,
#   'x_coordinate': 961.0,
#   'y_coordinate': 855.0,
#   'is_fraudulent': True},
#  '500191': {'user_id': '22',
#   'transaction_id': '500191',
#   'description': 'BENTLEY COLLEGE',
#   'amount': 96.65,
#   'x_coordinate': 966.0,
#   'y_coordinate': 721.0,
#   'is_fraudulent': True},
#  '500192': {'user_id': '22',
#   'transaction_id': '500192',
#   'description': 'CVS PHARMACY',
#   'amount': 28.8,
#   'x_coordinate': 885.0,
#   'y_coordinate': 912.0,
#   'is_fraudulent': True},
#  '500193': {'user_id': '22',
#   'transaction_id': '500193',
#   'description': 'GULF OIL',
#   'amount': 33.7,
#   'x_coordinate': 938.0,
#   'y_coordinate': 961.0,
#   'is_fraudulent': True},
#  '500194': {'user_id': '22',
#   'transaction_id': '500194',
#   'description': 'USAIRWAY',
#   'amount': 84.27,
#   'x_coordinate': 909.0,
#   'y_coordinate': 700.0,
#   'is_fraudulent': True},
#  '500195': {'user_id': '22',
#   'transaction_id': '500195',
#   'description': 'COPLEY DARTMOUTH GARAG',
#   'amount': 61.36,
#   'x_coordinate': 904.0,
#   'y_coordinate': 977.0,
#   'is_fraudulent': True},
#  '500196': {'user_id': '22',
#   'transaction_id': '500196',
#   'description': 'REDBOX DVD',
#   'amount': 44.55,
#   'x_coordinate': 815.0,
#   'y_coordinate': 921.0,
#   'is_fraudulent': True},
#  '500197': {'user_id': '22',
#   'transaction_id': '500197',
#   'description': 'EXPEDIA TRAVEL',
#   'amount': 72.98,
#   'x_coordinate': 748.0,
#   'y_coordinate': 975.0,
#   'is_fraudulent': True},
#  '500198': {'user_id': '22',
#   'transaction_id': '500198',
#   'description': 'WHOLEFDS WOB 10233 SWH',
#   'amount': 51.05,
#   'x_coordinate': 851.0,
#   'y_coordinate': 751.0,
#   'is_fraudulent': True},
#  '500199': {'user_id': '22',
#   'transaction_id': '500199',
#   'description': 'SUPERCUTS',
#   'amount': 31.54,
#   'x_coordinate': 890.0,
#   'y_coordinate': 753.0,
#   'is_fraudulent': True},
#  '500200': {'user_id': '22',
#   'transaction_id': '500200',
#   'description': 'GULF OIL',
#   'amount': 42.47,
#   'x_coordinate': 872.0,
#   'y_coordinate': 935.0,
#   'is_fraudulent': True},
#  '500201': {'user_id': '22',
#   'transaction_id': '500201',
#   'description': 'HYATT HOTELS MIAMI F&B',
#   'amount': 28.54,
#   'x_coordinate': 765.0,
#   'y_coordinate': 871.0,
#   'is_fraudulent': True},
#  '500202': {'user_id': '22',
#   'transaction_id': '500202',
#   'description': "MARIO'S ITALIAN RSTR",
#   'amount': 45.67,
#   'x_coordinate': 736.0,
#   'y_coordinate': 915.0,
#   'is_fraudulent': True},
#  '500203': {'user_id': '22',
#   'transaction_id': '500203',
#   'description': 'EXXONMOBIL',
#   'amount': 69.04,
#   'x_coordinate': 748.0,
#   'y_coordinate': 989.0,
#   'is_fraudulent': True},
#  '500204': {'user_id': '22',
#   'transaction_id': '500204',
#   'description': 'REDBOX DVD',
#   'amount': 37.75,
#   'x_coordinate': 958.0,
#   'y_coordinate': 749.0,
#   'is_fraudulent': True},
#  '500205': {'user_id': '22',
#   'transaction_id': '500205',
#   'description': 'INDIA CAFE',
#   'amount': 42.75,
#   'x_coordinate': 843.0,
#   'y_coordinate': 772.0,
#   'is_fraudulent': True},
#  '500206': {'user_id': '22',
#   'transaction_id': '500206',
#   'description': 'GREEN PAPAYA',
#   'amount': 21.12,
#   'x_coordinate': 762.0,
#   'y_coordinate': 756.0,
#   'is_fraudulent': True},
#  '500207': {'user_id': '22',
#   'transaction_id': '500207',
#   'description': 'PANERA BREAD',
#   'amount': 49.29,
#   'x_coordinate': 722.0,
#   'y_coordinate': 772.0,
#   'is_fraudulent': True},
#  '500208': {'user_id': '22',
#   'transaction_id': '500208',
#   'description': 'OUTBACK',
#   'amount': 31.33,
#   'x_coordinate': 731.0,
#   'y_coordinate': 857.0,
#   'is_fraudulent': True},
#  '500209': {'user_id': '22',
#   'transaction_id': '500209',
#   'description': 'THE HOME DEPOT',
#   'amount': 59.68,
#   'x_coordinate': 783.0,
#   'y_coordinate': 734.0,
#   'is_fraudulent': True},
#  '500210': {'user_id': '22',
#   'transaction_id': '500210',
#   'description': 'EXXONMOBIL',
#   'amount': 3986.97,
#   'x_coordinate': 80.0,
#   'y_coordinate': 139.0,
#   'is_fraudulent': True},
#  '500211': {'user_id': '22',
#   'transaction_id': '500211',
#   'description': 'FAMOUS AND BOLD',
#   'amount': 3849.71,
#   'x_coordinate': 183.0,
#   'y_coordinate': 101.0,
#   'is_fraudulent': True},
#  '500212': {'user_id': '22',
#   'transaction_id': '500212',
#   'description': 'whole flash',
#   'amount': 3825.42,
#   'x_coordinate': 65.0,
#   'y_coordinate': 160.0,
#   'is_fraudulent': True},
#  '500213': {'user_id': '22',
#   'transaction_id': '500213',
#   'description': 'CIKUIT CITY',
#   'amount': 3835.73,
#   'x_coordinate': 95.0,
#   'y_coordinate': 195.0,
#   'is_fraudulent': True},
#  '500214': {'user_id': '22',
#   'transaction_id': '500214',
#   'description': 'whole flash',
#   'amount': 4151.17,
#   'x_coordinate': 194.0,
#   'y_coordinate': 194.0,
#   'is_fraudulent': True},
#  '500215': {'user_id': '22',
#   'transaction_id': '500215',
#   'description': 'FAMOUS AND BOLD',
#   'amount': 4085.28,
#   'x_coordinate': 166.0,
#   'y_coordinate': 118.0,
#   'is_fraudulent': True},
#  '500216': {'user_id': '22',
#   'transaction_id': '500216',
#   'description': 'CAFE QWERTY',
#   'amount': 3943.04,
#   'x_coordinate': 195.0,
#   'y_coordinate': 185.0,
#   'is_fraudulent': True},
#  '500217': {'user_id': '22',
#   'transaction_id': '500217',
#   'description': 'CANADIAN PHARMACY',
#   'amount': 3852.81,
#   'x_coordinate': 58.0,
#   'y_coordinate': 92.0,
#   'is_fraudulent': True},
#  '500218': {'user_id': '22',
#   'transaction_id': '500218',
#   'description': 'EXPRESS FREEDOM',
#   'amount': 4016.02,
#   'x_coordinate': 192.0,
#   'y_coordinate': 172.0,
#   'is_fraudulent': True},
#  '500219': {'user_id': '22',
#   'transaction_id': '500219',
#   'description': 'hotel oasis',
#   'amount': 3955.33,
#   'x_coordinate': 136.0,
#   'y_coordinate': 61.0,
#   'is_fraudulent': True},
#  '500220': {'user_id': '23',
#   'transaction_id': '500220',
#   'description': 'USAIRWAY',
#   'amount': 102.46,
#   'x_coordinate': 786.0,
#   'y_coordinate': 881.0,
#   'is_fraudulent': True},
#  '500221': {'user_id': '23',
#   'transaction_id': '500221',
#   'description': 'PANERA BREAD',
#   'amount': 62.78,
#   'x_coordinate': 953.0,
#   'y_coordinate': 858.0,
#   'is_fraudulent': True},
#  '500222': {'user_id': '23',
#   'transaction_id': '500222',
#   'description': 'HMS HOST-BOS AIRPT',
#   'amount': 17.84,
#   'x_coordinate': 625.0,
#   'y_coordinate': 547.0,
#   'is_fraudulent': True},
#  '500223': {'user_id': '23',
#   'transaction_id': '500223',
#   'description': "REBECCA'S CAFE",
#   'amount': 75.38,
#   'x_coordinate': 574.0,
#   'y_coordinate': 616.0,
#   'is_fraudulent': True},
#  '500224': {'user_id': '23',
#   'transaction_id': '500224',
#   'description': 'THE GINGER PAD',
#   'amount': 62.26,
#   'x_coordinate': 562.0,
#   'y_coordinate': 780.0,
#   'is_fraudulent': True},
#  '500225': {'user_id': '23',
#   'transaction_id': '500225',
#   'description': 'OUTBACK',
#   'amount': 69.88,
#   'x_coordinate': 854.0,
#   'y_coordinate': 707.0,
#   'is_fraudulent': True},
#  '500226': {'user_id': '23',
#   'transaction_id': '500226',
#   'description': 'GREEN PAPAYA',
#   'amount': 100.12,
#   'x_coordinate': 815.0,
#   'y_coordinate': 508.0,
#   'is_fraudulent': True},
#  '500227': {'user_id': '23',
#   'transaction_id': '500227',
#   'description': 'CVS PHARMACY',
#   'amount': 41.11,
#   'x_coordinate': 970.0,
#   'y_coordinate': 755.0,
#   'is_fraudulent': True},
#  '500228': {'user_id': '23',
#   'transaction_id': '500228',
#   'description': 'GREEN PAPAYA',
#   'amount': 28.7,
#   'x_coordinate': 788.0,
#   'y_coordinate': 638.0,
#   'is_fraudulent': True},
#  '500229': {'user_id': '23',
#   'transaction_id': '500229',
#   'description': 'SATO RESTAURANT',
#   'amount': 65.9,
#   'x_coordinate': 509.0,
#   'y_coordinate': 870.0,
#   'is_fraudulent': True},
#  '500230': {'user_id': '23',
#   'transaction_id': '500230',
#   'description': "TRADER JOE'S",
#   'amount': 84.07,
#   'x_coordinate': 823.0,
#   'y_coordinate': 785.0,
#   'is_fraudulent': True},
#  '500231': {'user_id': '23',
#   'transaction_id': '500231',
#   'description': 'PANERA BREAD',
#   'amount': 87.64,
#   'x_coordinate': 809.0,
#   'y_coordinate': 760.0,
#   'is_fraudulent': True},
#  '500232': {'user_id': '23',
#   'transaction_id': '500232',
#   'description': 'PANERA BREAD',
#   'amount': 47.8,
#   'x_coordinate': 909.0,
#   'y_coordinate': 925.0,
#   'is_fraudulent': True},
#  '500233': {'user_id': '23',
#   'transaction_id': '500233',
#   'description': 'SUNOCO SVC STATION',
#   'amount': 78.62,
#   'x_coordinate': 947.0,
#   'y_coordinate': 962.0,
#   'is_fraudulent': True},
#  '500234': {'user_id': '23',
#   'transaction_id': '500234',
#   'description': '48HOURPRINT.COM',
#   'amount': 105.41,
#   'x_coordinate': 904.0,
#   'y_coordinate': 686.0,
#   'is_fraudulent': True},
#  '500235': {'user_id': '23',
#   'transaction_id': '500235',
#   'description': 'MARSHALLS',
#   'amount': 50.28,
#   'x_coordinate': 828.0,
#   'y_coordinate': 928.0,
#   'is_fraudulent': True},
#  '500236': {'user_id': '23',
#   'transaction_id': '500236',
#   'description': 'AMERCN SCTY FOR INFO S',
#   'amount': 60.58,
#   'x_coordinate': 662.0,
#   'y_coordinate': 931.0,
#   'is_fraudulent': True},
#  '500237': {'user_id': '23',
#   'transaction_id': '500237',
#   'description': 'PANERA BREAD',
#   'amount': 75.54,
#   'x_coordinate': 939.0,
#   'y_coordinate': 716.0,
#   'is_fraudulent': True},
#  '500238': {'user_id': '23',
#   'transaction_id': '500238',
#   'description': 'H & M',
#   'amount': 53.92,
#   'x_coordinate': 975.0,
#   'y_coordinate': 893.0,
#   'is_fraudulent': True},
#  '500239': {'user_id': '23',
#   'transaction_id': '500239',
#   'description': 'HOMEGOODS',
#   'amount': 80.48,
#   'x_coordinate': 882.0,
#   'y_coordinate': 726.0,
#   'is_fraudulent': True},
#  '500240': {'user_id': '23',
#   'transaction_id': '500240',
#   'description': 'AMERCN SCTY FOR INFO S',
#   'amount': 24.12,
#   'x_coordinate': 687.0,
#   'y_coordinate': 832.0,
#   'is_fraudulent': True},
#  '500241': {'user_id': '23',
#   'transaction_id': '500241',
#   'description': 'EXXONMOBIL',
#   'amount': 59.56,
#   'x_coordinate': 740.0,
#   'y_coordinate': 812.0,
#   'is_fraudulent': True},
#  '500242': {'user_id': '23',
#   'transaction_id': '500242',
#   'description': 'RANCHO ARGENTINO',
#   'amount': 67.21,
#   'x_coordinate': 938.0,
#   'y_coordinate': 620.0,
#   'is_fraudulent': True},
#  '500243': {'user_id': '23',
#   'transaction_id': '500243',
#   'description': 'BLACK DIAMOND COFFEE',
#   'amount': 64.96,
#   'x_coordinate': 842.0,
#   'y_coordinate': 613.0,
#   'is_fraudulent': True},
#  '500244': {'user_id': '23',
#   'transaction_id': '500244',
#   'description': 'SUNOCO SVC STATION',
#   'amount': 53.46,
#   'x_coordinate': 514.0,
#   'y_coordinate': 570.0,
#   'is_fraudulent': True},
#  '500245': {'user_id': '23',
#   'transaction_id': '500245',
#   'description': 'BARNES & NOBLE',
#   'amount': 32.06,
#   'x_coordinate': 768.0,
#   'y_coordinate': 639.0,
#   'is_fraudulent': True},
#  '500246': {'user_id': '23',
#   'transaction_id': '500246',
#   'description': 'SURF STYLE',
#   'amount': 81.61,
#   'x_coordinate': 793.0,
#   'y_coordinate': 997.0,
#   'is_fraudulent': True},
#  '500247': {'user_id': '23',
#   'transaction_id': '500247',
#   'description': 'LEGAL SEA FOODS',
#   'amount': 58.85,
#   'x_coordinate': 887.0,
#   'y_coordinate': 856.0,
#   'is_fraudulent': True},
#  '500248': {'user_id': '23',
#   'transaction_id': '500248',
#   'description': 'CIRCUIT CITY',
#   'amount': 72.75,
#   'x_coordinate': 947.0,
#   'y_coordinate': 557.0,
#   'is_fraudulent': True},
#  '500249': {'user_id': '23',
#   'transaction_id': '500249',
#   'description': 'STARBUCKS USA',
#   'amount': 77.65,
#   'x_coordinate': 666.0,
#   'y_coordinate': 640.0,
#   'is_fraudulent': True},
#  '500250': {'user_id': '23',
#   'transaction_id': '500250',
#   'description': 'WHOLEFDS WOB 10233 SWH',
#   'amount': 97.11,
#   'x_coordinate': 720.0,
#   'y_coordinate': 958.0,
#   'is_fraudulent': True},
#  '500251': {'user_id': '23',
#   'transaction_id': '500251',
#   'description': "JERRY'S FAMOUS DELI",
#   'amount': 71.55,
#   'x_coordinate': 920.0,
#   'y_coordinate': 851.0,
#   'is_fraudulent': True},
#  '500252': {'user_id': '23',
#   'transaction_id': '500252',
#   'description': 'GULF OIL',
#   'amount': 19.96,
#   'x_coordinate': 823.0,
#   'y_coordinate': 819.0,
#   'is_fraudulent': True},
#  '500253': {'user_id': '23',
#   'transaction_id': '500253',
#   'description': 'MARSHALLS',
#   'amount': 46.71,
#   'x_coordinate': 521.0,
#   'y_coordinate': 952.0,
#   'is_fraudulent': True},
#  '500254': {'user_id': '23',
# ...
#   'x_coordinate': 189.0,
#   'y_coordinate': 374.0,
#   'is_fraudulent': True},
#  '500916': {'user_id': '29',
#   'transaction_id': '500916',
#   'description': 'RANCHO ARGENTINO',
#   'amount': 556.54,
#   'x_coordinate': 252.0,
#   'y_coordinate': 153.0,
#   'is_fraudulent': True},
#  '500917': {'user_id': '29',
#   'transaction_id': '500917',
#   'description': 'THE HOME DEPOT',
#   'amount': 632.02,
#   'x_coordinate': 223.0,
#   'y_coordinate': 163.0,
#   'is_fraudulent': True},
#  '500918': {'user_id': '29',
#   'transaction_id': '500918',
#   'description': 'SUPERCUTS',
#   'amount': 922.87,
#   'x_coordinate': 230.0,
#   'y_coordinate': 281.0,
#   'is_fraudulent': True},
#  '500919': {'user_id': '29',
#   'transaction_id': '500919',
#   'description': 'THE HOME DEPOT',
#   'amount': 553.65,
#   'x_coordinate': 297.0,
#   'y_coordinate': 333.0,
#   'is_fraudulent': True},
#  '500920': {'user_id': '29',
#   'transaction_id': '500920',
#   'description': 'SURF STYLE',
#   'amount': 179.37,
#   'x_coordinate': 135.0,
#   'y_coordinate': 316.0,
#   'is_fraudulent': True},
#  '500921': {'user_id': '29',
#   'transaction_id': '500921',
#   'description': 'VERIZON WEB',
#   'amount': 1271.73,
#   'x_coordinate': 382.0,
#   'y_coordinate': 304.0,
#   'is_fraudulent': True},
#  '500922': {'user_id': '29',
#   'transaction_id': '500922',
#   'description': 'RANCHO ARGENTINO',
#   'amount': 672.71,
#   'x_coordinate': 118.0,
#   'y_coordinate': 213.0,
#   'is_fraudulent': True},
#  '500923': {'user_id': '29',
#   'transaction_id': '500923',
#   'description': 'BLOCKBUSTER VIDEO',
#   'amount': 695.76,
#   'x_coordinate': 276.0,
#   'y_coordinate': 110.0,
#   'is_fraudulent': True},
#  '500924': {'user_id': '29',
#   'transaction_id': '500924',
#   'description': 'THE GINGER PAD',
#   'amount': 1565.59,
#   'x_coordinate': 164.0,
#   'y_coordinate': 353.0,
#   'is_fraudulent': True},
#  '500925': {'user_id': '29',
#   'transaction_id': '500925',
#   'description': 'JULIOS LIQUORS',
#   'amount': 362.45,
#   'x_coordinate': 220.0,
#   'y_coordinate': 319.0,
#   'is_fraudulent': True},
#  '500926': {'user_id': '29',
#   'transaction_id': '500926',
#   'description': "MACY'S EAST",
#   'amount': 1294.8,
#   'x_coordinate': 236.0,
#   'y_coordinate': 372.0,
#   'is_fraudulent': True},
#  '500927': {'user_id': '29',
#   'transaction_id': '500927',
#   'description': 'HYATT HOTELS MIAMI F&B',
#   'amount': 1207.48,
#   'x_coordinate': 388.0,
#   'y_coordinate': 143.0,
#   'is_fraudulent': True},
#  '500928': {'user_id': '29',
#   'transaction_id': '500928',
#   'description': "REBECCA'S CAFE",
#   'amount': 1030.81,
#   'x_coordinate': 115.0,
#   'y_coordinate': 117.0,
#   'is_fraudulent': True},
#  '500929': {'user_id': '29',
#   'transaction_id': '500929',
#   'description': 'REDBOX DVD',
#   'amount': 602.31,
#   'x_coordinate': 313.0,
#   'y_coordinate': 181.0,
#   'is_fraudulent': True},
#  '500930': {'user_id': '29',
#   'transaction_id': '500930',
#   'description': 'CVS PHARMACY',
#   'amount': 1235.54,
#   'x_coordinate': 282.0,
#   'y_coordinate': 102.0,
#   'is_fraudulent': True},
#  '500931': {'user_id': '29',
#   'transaction_id': '500931',
#   'description': "MACY'S EAST",
#   'amount': 67.12,
#   'x_coordinate': 149.0,
#   'y_coordinate': 281.0,
#   'is_fraudulent': True},
#  '500932': {'user_id': '29',
#   'transaction_id': '500932',
#   'description': 'WHOLEFDS FRA 10156 SWH',
#   'amount': 1153.57,
#   'x_coordinate': 325.0,
#   'y_coordinate': 148.0,
#   'is_fraudulent': True},
#  '500933': {'user_id': '29',
#   'transaction_id': '500933',
#   'description': 'HOMEGOODS',
#   'amount': 1494.29,
#   'x_coordinate': 230.0,
#   'y_coordinate': 284.0,
#   'is_fraudulent': True},
#  '500934': {'user_id': '29',
#   'transaction_id': '500934',
#   'description': 'WAL-MART',
#   'amount': 480.01,
#   'x_coordinate': 308.0,
#   'y_coordinate': 142.0,
#   'is_fraudulent': True},
#  '500935': {'user_id': '29',
#   'transaction_id': '500935',
#   'description': 'STARBUCKS USA',
#   'amount': 841.43,
#   'x_coordinate': 208.0,
#   'y_coordinate': 206.0,
#   'is_fraudulent': True},
#  '500936': {'user_id': '29',
#   'transaction_id': '500936',
#   'description': 'MGH YAWKEY PRKNG GARAG',
#   'amount': 827.98,
#   'x_coordinate': 386.0,
#   'y_coordinate': 275.0,
#   'is_fraudulent': True},
#  '500937': {'user_id': '29',
#   'transaction_id': '500937',
#   'description': 'WHOLEFDS FRA 10156 SWH',
#   'amount': 150.41,
#   'x_coordinate': 321.0,
#   'y_coordinate': 174.0,
#   'is_fraudulent': True},
#  '500938': {'user_id': '29',
#   'transaction_id': '500938',
#   'description': 'SATO RESTAURANT',
#   'amount': 867.73,
#   'x_coordinate': 167.0,
#   'y_coordinate': 117.0,
#   'is_fraudulent': True},
#  '500939': {'user_id': '29',
#   'transaction_id': '500939',
#   'description': 'LORD & TAYLOR',
#   'amount': 11.22,
#   'x_coordinate': 376.0,
#   'y_coordinate': 278.0,
#   'is_fraudulent': True},
#  '500940': {'user_id': '29',
#   'transaction_id': '500940',
#   'description': 'SURF STYLE',
#   'amount': 1301.02,
#   'x_coordinate': 367.0,
#   'y_coordinate': 377.0,
#   'is_fraudulent': True},
#  '500941': {'user_id': '29',
#   'transaction_id': '500941',
#   'description': 'LEGAL SEA FOODS',
#   'amount': 345.74,
#   'x_coordinate': 117.0,
#   'y_coordinate': 277.0,
#   'is_fraudulent': True},
#  '500942': {'user_id': '29',
#   'transaction_id': '500942',
#   'description': 'STARBUCKS USA',
#   'amount': 508.42,
#   'x_coordinate': 306.0,
#   'y_coordinate': 236.0,
#   'is_fraudulent': True},
#  '500943': {'user_id': '29',
#   'transaction_id': '500943',
#   'description': 'BLOCKBUSTER VIDEO',
#   'amount': 321.49,
#   'x_coordinate': 101.0,
#   'y_coordinate': 306.0,
#   'is_fraudulent': True},
#  '500944': {'user_id': '29',
#   'transaction_id': '500944',
#   'description': 'LEGAL SEA FOODS',
#   'amount': 1408.67,
#   'x_coordinate': 396.0,
#   'y_coordinate': 138.0,
#   'is_fraudulent': True},
#  '500945': {'user_id': '29',
#   'transaction_id': '500945',
#   'description': "MARIO'S ITALIAN RSTR",
#   'amount': 25.0,
#   'x_coordinate': 199.0,
#   'y_coordinate': 368.0,
#   'is_fraudulent': True},
#  '500946': {'user_id': '29',
#   'transaction_id': '500946',
#   'description': 'STOP & SHOP',
#   'amount': 918.71,
#   'x_coordinate': 105.0,
#   'y_coordinate': 215.0,
#   'is_fraudulent': True},
#  '500947': {'user_id': '29',
#   'transaction_id': '500947',
#   'description': 'BORDERS BOOKS',
#   'amount': 0.91,
#   'x_coordinate': 209.0,
#   'y_coordinate': 317.0,
#   'is_fraudulent': True},
#  '500948': {'user_id': '29',
#   'transaction_id': '500948',
#   'description': 'BORDERS BOOKS',
#   'amount': 481.25,
#   'x_coordinate': 103.0,
#   'y_coordinate': 347.0,
#   'is_fraudulent': True},
#  '500949': {'user_id': '29',
#   'transaction_id': '500949',
#   'description': 'OUTBACK',
#   'amount': 590.22,
#   'x_coordinate': 177.0,
#   'y_coordinate': 275.0,
#   'is_fraudulent': True},
#  '500950': {'user_id': '29',
#   'transaction_id': '500950',
#   'description': 'SURF STYLE',
#   'amount': 696.26,
#   'x_coordinate': 388.0,
#   'y_coordinate': 333.0,
#   'is_fraudulent': True},
#  '500951': {'user_id': '29',
#   'transaction_id': '500951',
#   'description': 'TOM CAN COOK',
#   'amount': 962.5,
#   'x_coordinate': 225.0,
#   'y_coordinate': 252.0,
#   'is_fraudulent': True},
#  '500952': {'user_id': '29',
#   'transaction_id': '500952',
#   'description': "JERRY'S FAMOUS DELI",
#   'amount': 418.49,
#   'x_coordinate': 264.0,
#   'y_coordinate': 341.0,
#   'is_fraudulent': True},
#  '500953': {'user_id': '29',
#   'transaction_id': '500953',
#   'description': 'STARBUCKS USA',
#   'amount': 1450.62,
#   'x_coordinate': 134.0,
#   'y_coordinate': 382.0,
#   'is_fraudulent': True},
#  '500954': {'user_id': '29',
#   'transaction_id': '500954',
#   'description': 'AMERCN SCTY FOR INFO S',
#   'amount': 101.11,
#   'x_coordinate': 384.0,
#   'y_coordinate': 135.0,
#   'is_fraudulent': True},
#  '500955': {'user_id': '29',
#   'transaction_id': '500955',
#   'description': "TRADER JOE'S",
#   'amount': 535.06,
#   'x_coordinate': 360.0,
#   'y_coordinate': 124.0,
#   'is_fraudulent': True},
#  '500956': {'user_id': '29',
#   'transaction_id': '500956',
#   'description': 'STAPLES',
#   'amount': 131.69,
#   'x_coordinate': 101.0,
#   'y_coordinate': 293.0,
#   'is_fraudulent': True},
#  '500957': {'user_id': '29',
#   'transaction_id': '500957',
#   'description': 'CIRCUIT CITY',
#   'amount': 43.56,
#   'x_coordinate': 383.0,
#   'y_coordinate': 215.0,
#   'is_fraudulent': True},
#  '500958': {'user_id': '29',
#   'transaction_id': '500958',
#   'description': 'USAIRWAY',
#   'amount': 1030.6,
#   'x_coordinate': 255.0,
#   'y_coordinate': 201.0,
#   'is_fraudulent': True},
#  '500959': {'user_id': '29',
#   'transaction_id': '500959',
#   'description': 'OUTBACK',
#   'amount': 721.51,
#   'x_coordinate': 319.0,
#   'y_coordinate': 160.0,
#   'is_fraudulent': True},
#  '500960': {'user_id': '29',
#   'transaction_id': '500960',
#   'description': 'LORD & TAYLOR',
#   'amount': 306.36,
#   'x_coordinate': 138.0,
#   'y_coordinate': 317.0,
#   'is_fraudulent': True},
#  '500961': {'user_id': '29',
#   'transaction_id': '500961',
#   'description': 'H & M',
#   'amount': 553.04,
#   'x_coordinate': 349.0,
#   'y_coordinate': 146.0,
#   'is_fraudulent': True},
#  '500962': {'user_id': '29',
#   'transaction_id': '500962',
#   'description': 'AMAZON.COM',
#   'amount': 1132.37,
#   'x_coordinate': 265.0,
#   'y_coordinate': 143.0,
#   'is_fraudulent': True},
#  '500963': {'user_id': '29',
#   'transaction_id': '500963',
#   'description': 'HOMEGOODS',
#   'amount': 615.37,
#   'x_coordinate': 337.0,
#   'y_coordinate': 264.0,
#   'is_fraudulent': True},
#  '500964': {'user_id': '29',
#   'transaction_id': '500964',
#   'description': 'AMAZON.COM',
#   'amount': 515.95,
#   'x_coordinate': 259.0,
#   'y_coordinate': 330.0,
#   'is_fraudulent': True},
#  '500965': {'user_id': '29',
#   'transaction_id': '500965',
#   'description': 'REDBOX DVD',
#   'amount': 1153.67,
#   'x_coordinate': 268.0,
#   'y_coordinate': 196.0,
#   'is_fraudulent': True},
#  '500966': {'user_id': '29',
#   'transaction_id': '500966',
#   'description': 'WHOLEFDS FRA 10156 SWH',
#   'amount': 325.43,
#   'x_coordinate': 119.0,
#   'y_coordinate': 322.0,
#   'is_fraudulent': True},
#  '500967': {'user_id': '29',
#   'transaction_id': '500967',
#   'description': '48HOURPRINT.COM',
#   'amount': 1274.23,
#   'x_coordinate': 210.0,
#   'y_coordinate': 376.0,
#   'is_fraudulent': True},
#  '500968': {'user_id': '29',
#   'transaction_id': '500968',
#   'description': 'PEPPERONI EXPRESS',
#   'amount': 1123.1,
#   'x_coordinate': 178.0,
#   'y_coordinate': 134.0,
#   'is_fraudulent': True},
#  '500969': {'user_id': '29',
#   'transaction_id': '500969',
#   'description': 'MASSPORT AUTH LOGAN PK',
#   'amount': 739.88,
#   'x_coordinate': 260.0,
#   'y_coordinate': 121.0,
#   'is_fraudulent': True},
#  '500970': {'user_id': '29',
#   'transaction_id': '500970',
#   'description': 'BENTLEY COLLEGE',
#   'amount': 432.91,
#   'x_coordinate': 377.0,
#   'y_coordinate': 347.0,
#   'is_fraudulent': True},
#  '500971': {'user_id': '29',
#   'transaction_id': '500971',
#   'description': 'SUPERCUTS',
#   'amount': 312.36,
#   'x_coordinate': 388.0,
#   'y_coordinate': 254.0,
#   'is_fraudulent': True},
#  '500972': {'user_id': '29',
#   'transaction_id': '500972',
#   'description': 'SATO RESTAURANT',
#   'amount': 244.56,
#   'x_coordinate': 180.0,
#   'y_coordinate': 296.0,
#   'is_fraudulent': True},
#  '500973': {'user_id': '29',
#   'transaction_id': '500973',
#   'description': 'HMS HOST-BOS AIRPT',
#   'amount': 244.98,
#   'x_coordinate': 151.0,
#   'y_coordinate': 231.0,
#   'is_fraudulent': True},
#  '500974': {'user_id': '29',
#   'transaction_id': '500974',
#   'description': 'EXPEDIA TRAVEL',
#   'amount': 1318.52,
#   'x_coordinate': 255.0,
#   'y_coordinate': 161.0,
#   'is_fraudulent': True},
#  '500975': {'user_id': '29',
#   'transaction_id': '500975',
#   'description': 'VERIZON WEB',
#   'amount': 774.47,
#   'x_coordinate': 254.0,
#   'y_coordinate': 348.0,
#   'is_fraudulent': True},
#  '500976': {'user_id': '29',
#   'transaction_id': '500976',
#   'description': 'COPLEY DARTMOUTH GARAG',
#   'amount': 49.07,
#   'x_coordinate': 253.0,
#   'y_coordinate': 383.0,
#   'is_fraudulent': True},
#  '500977': {'user_id': '29',
#   'transaction_id': '500977',
#   'description': 'PANERA BREAD',
#   'amount': 572.76,
#   'x_coordinate': 138.0,
#   'y_coordinate': 382.0,
#   'is_fraudulent': True},
#  '500978': {'user_id': '29',
#   'transaction_id': '500978',
#   'description': 'TOM CAN COOK',
#   'amount': 1337.9,
#   'x_coordinate': 290.0,
#   'y_coordinate': 227.0,
#   'is_fraudulent': True},
#  '500979': {'user_id': '29',
#   'transaction_id': '500979',
#   'description': 'OUTBACK',
#   'amount': 1133.28,
#   'x_coordinate': 361.0,
#   'y_coordinate': 331.0,
#   'is_fraudulent': True},
#  '500980': {'user_id': '29',
#   'transaction_id': '500980',
#   'description': 'coffee YYY',
#   'amount': 621.01,
#   'x_coordinate': 671.0,
#   'y_coordinate': 576.0,
#   'is_fraudulent': True},
#  '500981': {'user_id': '29',
#   'transaction_id': '500981',
#   'description': 'hotel oasis',
#   'amount': 769.73,
#   'x_coordinate': 661.0,
#   'y_coordinate': 509.0,
#   'is_fraudulent': True},
#  '500982': {'user_id': '29',
#   'transaction_id': '500982',
#   'description': 'coffee YYY',
#   'amount': 702.11,
#   'x_coordinate': 575.0,
#   'y_coordinate': 504.0,
#   'is_fraudulent': True},
#  '500983': {'user_id': '29',
#   'transaction_id': '500983',
#   'description': 'FAMOUS AND BOLD',
#   'amount': 639.82,
#   'x_coordinate': 532.0,
#   'y_coordinate': 605.0,
#   'is_fraudulent': True},
#  '500984': {'user_id': '29',
#   'transaction_id': '500984',
#   'description': 'CANADIAN PHARMACY',
#   'amount': 582.13,
#   'x_coordinate': 683.0,
#   'y_coordinate': 529.0,
#   'is_fraudulent': True},
#  '500985': {'user_id': '29',
#   'transaction_id': '500985',
#   'description': 'food ASDFG',
#   'amount': 659.97,
#   'x_coordinate': 503.0,
#   'y_coordinate': 576.0,
#   'is_fraudulent': True},
#  '500986': {'user_id': '29',
#   'transaction_id': '500986',
#   'description': 'DIAMOND AAA',
#   'amount': 612.54,
#   'x_coordinate': 609.0,
#   'y_coordinate': 596.0,
#   'is_fraudulent': True},
#  '500987': {'user_id': '29',
#   'transaction_id': '500987',
#   'description': 'CAFE QWERTY',
#   'amount': 521.88,
#   'x_coordinate': 580.0,
#   'y_coordinate': 646.0,
#   'is_fraudulent': True},
#  '500988': {'user_id': '29',
#   'transaction_id': '500988',
#   'description': 'AMAZON.TW',
#   'amount': 772.33,
#   'x_coordinate': 558.0,
#   'y_coordinate': 671.0,
#   'is_fraudulent': True},
#  '500989': {'user_id': '29',
#   'transaction_id': '500989',
#   'description': 'hotel oasis',
#   'amount': 594.85,
#   'x_coordinate': 571.0,
#   'y_coordinate': 601.0,
#   'is_fraudulent': True},
#  '500990': {'user_id': '30',
#   'transaction_id': '500990',
#   'description': 'RANCHO ARGENTINO',
#   'amount': 1190.84,
#   'x_coordinate': 381.0,
#   'y_coordinate': 388.0,
#   'is_fraudulent': True},
#  '500991': {'user_id': '30',
#   'transaction_id': '500991',
#   'description': 'JULIOS LIQUORS',
#   'amount': 1392.94,
#   'x_coordinate': 353.0,
#   'y_coordinate': 349.0,
#   'is_fraudulent': True},
#  '500992': {'user_id': '30',
#   'transaction_id': '500992',
#   'description': 'H & M',
#   'amount': 1229.44,
#   'x_coordinate': 244.0,
#   'y_coordinate': 219.0,
#   'is_fraudulent': True},
#  '500993': {'user_id': '30',
#   'transaction_id': '500993',
#   'description': 'GREEN PAPAYA',
#   'amount': 1715.38,
#   'x_coordinate': 330.0,
#   'y_coordinate': 153.0,
#   'is_fraudulent': True},
#  '500994': {'user_id': '30',
#   'transaction_id': '500994',
#   'description': 'BLOCKBUSTER VIDEO',
#   'amount': 519.74,
#   'x_coordinate': 123.0,
#   'y_coordinate': 118.0,
#   'is_fraudulent': True},
#  '500995': {'user_id': '30',
#   'transaction_id': '500995',
#   'description': "REBECCA'S CAFE",
#   'amount': 444.06,
#   'x_coordinate': 292.0,
#   'y_coordinate': 369.0,
#   'is_fraudulent': True},
#  '500996': {'user_id': '30',
#   'transaction_id': '500996',
#   'description': 'USAIRWAY',
#   'amount': 500.5,
#   'x_coordinate': 360.0,
#   'y_coordinate': 337.0,
#   'is_fraudulent': True},
#  '500997': {'user_id': '30',
#   'transaction_id': '500997',
#   'description': 'STARBUCKS USA',
#   'amount': 365.11,
#   'x_coordinate': 385.0,
#   'y_coordinate': 303.0,
#   'is_fraudulent': True},
#  '500998': {'user_id': '30',
#   'transaction_id': '500998',
#   'description': 'MASSPORT AUTH LOGAN PK',
#   'amount': 668.56,
#   'x_coordinate': 394.0,
#   'y_coordinate': 275.0,
#   'is_fraudulent': True},
#  '500999': {'user_id': '30',
#   'transaction_id': '500999',
#   'description': 'AMERCN SCTY FOR INFO S',
#   'amount': 120.34,
#   'x_coordinate': 342.0,
#   'y_coordinate': 203.0,
#   'is_fraudulent': True},
#  ...}

# %% [markdown]
# ## 2. Distance Module

# %%
import math

def distance_between_transactions(transaction1, transaction2):
    # Calculate the distance between two transactions belonging to the same user
    x1 = transaction1['x_coordinate']
    y1 = transaction1['y_coordinate']
    x2 = transaction2['x_coordinate']
    y2 = transaction2['y_coordinate']
    distance = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
    return distance


def distance_between_users_transactions(user1_transactions, user2_transactions):
    # Calculate the distance between the transactions of two different users
    distances = []
    for transaction1 in user1_transactions:
        for transaction2 in user2_transactions:
            distance = distance_between_transactions(transaction1, transaction2)
            distances.append(distance)
    return distances

# %%
# Assuming you already have a transactions_data dictionary containing the transaction data
# For example, transactions_data = read_transactions_file('transactions/transaction.txt')

# Get all the transactions belonging to user1
user1_transactions = [transaction_data for transaction_data in transactions_data.values() if transaction_data['user_id'] == '21']

# Get all the transactions belonging to user2
user2_transactions = [transaction_data for transaction_data in transactions_data.values() if transaction_data['user_id'] == '22']

# Calculate the distance between two transactions of user1
distance = distance_between_transactions(user1_transactions[0], user1_transactions[1])

# Calculate the distances between the transactions of user1 and user2
distances = distance_between_users_transactions(user1_transactions, user2_transactions)

# %%
print('The distance between the first two transactions of user1 is: {}'.format(distance))
print('The distances between the transactions of user1 and user2 are: {}'.format(distances))
# Out:
# The distance between the first two transactions of user1 is: 172.72232050317064
# The distances between the transactions of user1 and user2 are: [197.9520143873257, 86.33075929238663, 106.53168542738823, 238.83885781003056, 61.326992425847855, 156.02884348735012, 181.37254478007415, 260.71632093139084, 111.16204388189342, 130.23056476879765, 47.50789408087881, 111.83022847155415, 56.00892785976178, 33.24154027718932, 261.5893728728291, 125.29964086141668, 70.00714249274856, 185.5693940282179, 143.69411957348845, 120.70211265756701, 73.06161783043132, 71.50524456289902, 149.11069713471264, 107.35455276791944, 202.89159667172024, 130.06152390311286, 45.09988913511872, 178.39843048636948, 241.49741199441456, 96.08329719571451, 255.8378392654222, 209.40391591371923, 196.16319736382766, 251.66843266488547, 88.61715409558128, 127.57742747053649, 202.7732724004818, 130.29965464267354, 175.60182231400674, 141.8731828077456, 185.776747737708, 194.99743588057768, 47.29693436154187, 267.15164233071823, 162.3730273167314, 118.33849753989612, 170.07351351694948, 113.65298060323803, 64.8459713474939, 51.0098029794274, 79.05694150420949, 166.00301202086666, 160.79800993793424, 54.08326913195984, 210.23796041628637, 129.4488315899375, 205.5723716845238, 176.11359970201053, 43.73785545725808, 232.4585984643287, 221.02036105300343, 62.68173577685928, 189.87364219396014, 172.2614292289484, 266.5933232472261, 58.25804665451803, 98.6154146165801, 234.01922997907673, 142.66744548074027, 43.04648650006177, 178.54971296532514, 59.481089431852205, 45.0111097397076, 111.0, 177.91290003819284, 159.05030650709227, 186.62529303392935, 251.7478897627545, 128.41339493993607, 220.592384274707, 126.21014222319853, 88.76936408468859, 157.00318468107582, 212.96009015775704, 60.41522986797286, 222.89908030317218, 179.76929659983654, 258.6426105652354, 33.24154027718932, 6.324555320336759, 180.3995565404749, 166.1836333698358, 217.95412361320444, 270.65106687393643, 74.24284477308234, 44.384682042344295, 122.00409829181969, 162.88953311984167, 183.88311504866346, 103.16006979447037, 1012.8533951169834, 958.7058985945586, 1012.3171439820626, 967.5334619536422, 889.2811703842605, 959.8400908484705, 894.215298460052, 1059.1718463025725, 904.8497112780664, 1020.3626806190042, 140.0, 120.14990636700472, 101.6070863670443, 147.6787053031005, 111.40017953306898, 175.41949720598336, 52.392747589718944, 180.27756377319946, 155.95512174981621, 189.46503635235712, 165.95180023127196, 137.0875632579411, 158.80806024884254, 205.91260281974002, 157.33403954643762, 131.24404748406687, 112.29425630903836, 265.9793225045887, 52.20153254455275, 118.92854997854805, 241.91940806805889, 241.8677324489565, 97.51410154434076, 144.06942770761603, 189.58902921846507, 163.62457028209425, 213.45959805077868, 100.42410069301094, 108.07404868885037, 261.9790067925291, 130.0, 111.23398761170077, 251.33443854752576, 150.65855435387664, 224.43707358633955, 97.082439194738, 248.07257002740147, 61.84658438426491, 149.57606760441325, 52.92447448959697, 167.17057157286985, 252.2478939456185, 138.6001443000692, 147.05441169852742, 61.204574992397426, 259.2778432492835, 120.24142381059865, 286.2481440987871, 237.54157530840786, 127.58134659894448, 160.15305179733542, 183.84776310850236, 194.09533739891847, 139.05394636614957, 176.58142597679972, 208.83007446246816, 251.66843266488547, 118.71394189394942, 151.79591562357663, 242.42524621004307, 171.71196813268432, 173.95401691251627, 17.46424919657298, 260.4400122868988, 167.28717822953436, 156.28499608087785, 141.66156853571826, 227.69277546729498, 228.7116088002531, 215.5736533067063, 201.1889659002203, 222.44325119005072, 133.6899397860587, 161.7714437099453, 174.20103329199858, 205.91260281974002, 253.69272752682525, 119.20570456148481, 221.82200071228283, 289.0121104729004, 235.6692597688549, 261.45171638373307, 179.41293152947478, 249.95399576722113, 221.93016919743022, 232.01077561182368, 128.76334882255898, 149.4824404403407, 145.43727170158274, 179.0111728356641, 180.8009955724802, 58.137767414994535, 88.45903006477066, 16 ...

# %% [markdown]
# ## 3. statistics_module
# You will implement a statistics_module. This module will contain the following functions:
#
# a) A function that returns the average transactions of any user and of all users.
#
# b) A function that returns the mode of transactions of any user and that of all users.
#
# c) A function that returns the median of all transactions of a user and that of all users.
#
# d) A function that returns the interquartile range of any user’s transactions and of all users.
#
# e) A function that returns the location centroid of any user, based on their transaction locations.
#
# f) A function that computes the standard deviation of any specific user’s transactions.
#
# g) A function that determines whether a transaction is fraudulent or not. It should provide details of such transactions.
#
# h) A function that returns an abnormal transaction for any given user.
#
# i) A function that computes the Z score of any user’s transactions and for all users’ transactions.
#
# j) A function that computes those frequencies of transactions at any given location.
#
# k) A function that returns the outlier of any location and of any user.
#
# l) A function that returns the nth percentiles of transactions of any user and of all users

# %% [markdown]
# ## a) A function that returns the average transactions of any user and of all users.

# %%
def average_transactions(transaction_data, user_id=None):
    """
    Returns the average transactions of any user and of all users.
    If user_id is not None, returns the average transactions of the specified user.
    """
    if user_id is not None:
        transactions = [t['amount'] for t in transaction_data.values() if t['user_id'] == user_id]
    else:
        transactions = [t['amount'] for t in transaction_data.values()]
    return sum(transactions) / len(transactions)

# %% [markdown]
# ## b) A function that returns the mode of transactions of any user and that of all users.

# %%
def mode_transactions(user_transactions, all_transactions):
    # Function to compute the mode of transactions of a specific user and of all users
    
    user_amounts = [transaction['amount'] for transaction in user_transactions]
    all_amounts = [transaction['amount'] for transaction in all_transactions]
    
    user_mode = max(set(user_amounts), key=user_amounts.count)
    all_mode = max(set(all_amounts), key=all_amounts.count)
    
    return {'user_mode': user_mode, 'all_mode': all_mode}

# %% [markdown]
# ## c) A function that returns the median of all transactions of a user and that of all users.

# %%
def median_transactions(user_transactions, all_transactions):
    # Function to compute the median of transactions of a specific user and of all users
    
    user_amounts = sorted([transaction['amount'] for transaction in user_transactions])
    all_amounts = sorted([transaction['amount'] for transaction in all_transactions])
    
    user_len = len(user_amounts)
    all_len = len(all_amounts)
    
    if user_len % 2 == 0:
        user_median = (user_amounts[user_len//2] + user_amounts[user_len//2 - 1])/2
    else:
        user_median = user_amounts[user_len//2]
        
    if all_len % 2 == 0:
        all_median = (all_amounts[all_len//2] + all_amounts[all_len//2 - 1])/2
    else:
        all_median = all_amounts[all_len//2]
    
    return {'user_median': user_median, 'all_median': all_median}

# %% [markdown]
# ## d) A function that returns the interquartile range of any user’s transactions and of all users.

# %%
def interquartile_range(user_transactions, all_transactions):
    # Function to compute the interquartile range of a specific user's transactions and of all users
    
    user_amounts = sorted([transaction['amount'] for transaction in user_transactions])
    all_amounts = sorted([transaction['amount'] for transaction in all_transactions])
    
    user_len = len(user_amounts)
    all_len = len(all_amounts)
    
    user_q1 = user_amounts[user_len//4]
    user_q3 = user_amounts[3*user_len//4]
    user_iqr = user_q3 - user_q1
    
    all_q1 = all_amounts[all_len//4]
    all_q3 = all_amounts[3*all_len//4]
    all_iqr = all_q3 - all_q1
    
    return {'user_iqr': user_iqr, 'all_iqr': all_iqr}

# %% [markdown]
# ## e) A function that returns the location centroid of any user, based on their transaction locations.

# %%
def location_centroid(user_transactions):
    # Function to compute the location centroid of a specific user, based on their transaction locations
    
    user_x = [transaction['x_coordinate'] for transaction in user_transactions]
    user_y = [transaction['y_coordinate'] for transaction in user_transactions]
    
    user_centroid_x = sum(user_x)/len(user_x)
    user_centroid_y = sum(user_y)/len(user_y)
    
    return {'user_centroid': (user_centroid_x, user_centroid_y)}

# %% [markdown]
# ## f) A function that computes the standard deviation of any specific user’s transactions.

# %%
import numpy as np
def compute_std_dev(user_id, transactions):
    # Get a list of transaction amounts for the user
    amounts = [t['amount'] for t in transactions.values() if t['user_id'] == user_id]
    # Compute the standard deviation of the transaction amounts
    std_dev = math.sqrt(sum((x - np.mean(amounts)) ** 2 for x in amounts) / len(amounts))
    return std_dev

# %% [markdown]
# ## g) A function that determines whether a transaction is fraudulent or not. It should provide details of such transactions.

# %%
def is_fraudulent(transaction_data, transaction_id):
    transaction = transaction_data.get(transaction_id)
    if not transaction:
        raise ValueError(f"Transaction ID {transaction_id} not found.")
    
    user_transactions = [t for t in transaction_data.values() if t['user_id'] == transaction['user_id']]
    amounts = [t['amount'] for t in user_transactions]
    amount_mean = np.mean(amounts)
    amount_std = np.std(amounts)
    
    x = transaction['x_coordinate']
    y = transaction['y_coordinate']
    locations = [(t['x_coordinate'], t['y_coordinate']) for t in transaction_data.values()]
    centroid = np.mean(locations, axis=0)
    location_std = np.std(locations, axis=0)
    
    if (transaction['amount'] - amount_mean) > (3 * amount_std):
        return True, transaction
    elif np.abs((x - centroid[0])/location_std[0]) > 2 or np.abs((y - centroid[1])/location_std[1]) > 2:
        return True , transaction
    else:
        return False , transaction

# %% [markdown]
# ## h) A function that returns an abnormal transaction for any given user.

# %%
def get_abnormal_transaction(user_id):
    transactions = []
    for transaction_id in transactions_data.keys():
        if transactions_data[transaction_id]['user_id'] == user_id:
            transactions.append(transactions_data[transaction_id]['amount'])
    q1, q3 = np.percentile(transactions, [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    abnormal_transactions = []
    for transaction_id in transactions_data.keys():
        if transactions_data[transaction_id]['user_id'] == user_id and (transactions_data[transaction_id]['amount'] < lower_bound or transactions_data[transaction_id]['amount'] > upper_bound):
            abnormal_transactions.append(transactions_data[transaction_id])
    return abnormal_transactions

# %% [markdown]
# ## i) A function that computes the Z score of any user’s transactions and for all users’ transactions.

# %%
def compute_z_score(user_id=None):
    transactions = transactions_data.values()
    if user_id:
        user_transactions = [t for t in transactions if t['user_id'] == user_id]
        amounts = [t['amount'] for t in user_transactions]
        mean = np.mean(amounts)
        std = np.std(amounts)
        z_scores = [(t['transaction_id'], (t['amount'] - mean) / std) for t in user_transactions]
    else:
        amounts = [t['amount'] for t in transactions]
        mean = np.mean(amounts)
        std = np.std(amounts)
        z_scores = [(t['transaction_id'], (t['amount'] - mean) / std) for t in transactions]
    return z_scores

# %% [markdown]
# ## j) A function that computes those frequencies of transactions at any given location.

# %%
def compute_location_frequency(x, y):
    transactions = transactions_data.values()
    location_transactions = [t for t in transactions if t['x_coordinate'] == x and t['y_coordinate'] == y]
    frequency = len(location_transactions) / len(transactions)
    return frequency

# %% [markdown]
# ## k) A function that returns the outlier of any location and of any user.

# %%
def find_outliers(user_id, transactions):
    # Get a list of transaction locations for the user
    locations = [(t['x_coordinate'], t['y_coordinate']) for t in transactions.values() if t['user_id'] == user_id]
    # Compute the centroid of the user's transaction locations
    centroid = (sum([x[0] for x in locations]) / len(locations), sum([x[1] for x in locations]) / len(locations))
    # Compute the distances of each transaction from the centroid
    distances = [math.sqrt((x[0] - centroid[0]) ** 2 + (x[1] - centroid[1]) ** 2) for x in locations]
    # Compute the median and interquartile range of the distances
    median = np.median(distances)
    q1 = np.percentile(distances, 25)
    q3 = np.percentile(distances, 75)
    iqr = q3 - q1
    # Identify outliers as any transactions more than 1.5 times the interquartile range from the median
    outliers = [t for t in transactions.values() if t['user_id'] == user_id and math.sqrt((t['x_coordinate'] - centroid[0]) ** 2 + (t['y_coordinate'] - centroid[1]) ** 2) > median + 1.5 * iqr]
    return outliers

# %% [markdown]
# ## l) A function that returns the nth percentiles of transactions of any user and of all users

# %%
def compute_percentiles(user_id, transactions, percentiles):
    # Get a list of transaction amounts for the user
    amounts = [t['amount'] for t in transactions.values() if t['user_id'] == user_id]
    # Compute the specified percentiles of the transaction amounts
    percentiles_dict = {}
    for p in percentiles:
        percentiles_dict[p] = np.percentile(amounts, p * 100)
    return percentiles_dict

# %%
print('average_transactions', average_transactions(transactions_data, "21"))
print("mode of transaction", mode_transactions(user1_transactions, transactions_data.values()))
print("median of transaction", median_transactions(user1_transactions, transactions_data.values()))
print("compute_std_dev", compute_std_dev("21", transactions_data))
print("find_abnormal_transaction", is_fraudulent(transactions_data, "500105"))
print("get_abnormal_transaction", get_abnormal_transaction("21"))
print("compute_z_score", compute_z_score("21"))
print("compute_location_frequency", compute_location_frequency(133, 191.0))
print("find_outliers", find_outliers("21", transactions_data))
print("compute_percentiles", compute_percentiles("21", transactions_data, [0.25, 0.5, 0.75]))
# Out:
# average_transactions 408.64609090909096
# mode of transaction {'user_mode': 3.43, 'all_mode': 38.85}
# median of transaction {'user_median': 54.745, 'all_median': 92.69999999999999}
# compute_std_dev 1129.6828600429055
# find_abnormal_transaction (True, {'user_id': '21', 'transaction_id': '500105', 'description': 'HOTEL PLEASURE', 'amount': 3976.08, 'x_coordinate': 133.0, 'y_coordinate': 191.0, 'is_fraudulent': True})
# get_abnormal_transaction [{'user_id': '21', 'transaction_id': '500100', 'description': 'HOTEL PLEASURE', 'amount': 4042.34, 'x_coordinate': 189.0, 'y_coordinate': 81.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500101', 'description': 'CAFE QWERTY', 'amount': 3949.97, 'x_coordinate': 68.0, 'y_coordinate': 154.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500102', 'description': 'whole flash', 'amount': 4134.79, 'x_coordinate': 191.0, 'y_coordinate': 96.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500103', 'description': 'AMAZON.TW', 'amount': 4038.09, 'x_coordinate': 163.0, 'y_coordinate': 131.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500104', 'description': 'USAIRWAY', 'amount': 3874.92, 'x_coordinate': 173.0, 'y_coordinate': 51.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500105', 'description': 'HOTEL PLEASURE', 'amount': 3976.08, 'x_coordinate': 133.0, 'y_coordinate': 191.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500106', 'description': 'coffee YYY', 'amount': 3855.62, 'x_coordinate': 91.0, 'y_coordinate': 127.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500107', 'description': 'CANADIAN PHARMACY', 'amount': 4070.97, 'x_coordinate': 144.0, 'y_coordinate': 126.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500108', 'description': 'CIKUIT CITY', 'amount': 3937.79, 'x_coordinate': 184.0, 'y_coordinate': 57.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500109', 'description': 'CAFE QWERTY', 'amount': 3914.93, 'x_coordinate': 199.0, 'y_coordinate': 121.0, 'is_fraudulent': True}]
# compute_z_score [('500000', -0.32938101839923345), ('500001', -0.2972481063369744), ('500002', -0.30758729126499607), ('500003', -0.3201129305399538), ('500004', -0.3527769651156386), ('500005', -0.30305504581709614), ('500006', -0.3200863744142825), ('500007', -0.30511757157756625), ('500008', -0.2975844839288107), ('500009', -0.3024973671779991), ('500010', -0.31527086362588885), ('500011', -0.3443409691940593), ('500012', -0.2917863964905794), ('500013', -0.3132260419491996), ('500014', -0.3066047146151584), ('500015', -0.3473152552692436), ('500016', -0.3303281868815094), ('500017', -0.3306380083476745), ('500018', -0.30709157691913197), ('500019', -0.29494657544546277), ('500020', -0.3184044864551009), ('500021', -0.32144958886540864), ('500022', -0.31668719032835757), ('500023', -0.2861830539739375), ('500024', -0.3278496151521892), ('500025', -0.3170589760877556), ('500026', -0.3203607877128858), ('500027', -0.3056663981747728), ('500028', -0.3293633143154526), ('500029', -0.32885874792769815), ('500030', -0.3325057891865551), ('500031', -0.33782586636270323), ('500032', -0.34238466793627437), ('500033', -0.3090655822606978), ('500034', -0.31905068551310223), ('500035', -0.3271060436333931), ('500036', -0.30558672979775897), ('500037', -0.3056132859234303), ('500038', -0.30665782686650095), ('500039', -0.34800571453669715), ('500040', -0.3119867560845395), ('500041', -0.3051972399545801), ('500042', -0.35869898114033594), ('500043', -0.3446419386183339), ('500044', -0.28301402297716377), ('500045', -0.27379904736922667), ('500046', -0.30388713775479653), ('500047', -0.29229981492022433), ('500048', -0.3126595112682122), ('500049', -0.28849343690733964), ('500050', -0.29228211083644345), ('500051', -0.33966709107591253), ('500052', -0.3031435662360005), ('500053', -0.28936093701260174), ('500054', -0.3370468866763454), ('500055', -0.3242822422703461), ('500056', -0.31289851639925376), ('500057', -0.30473693377627775), ('500058', -0.2798007317709379), ('500059', -0.32314032886648064), ('500060', -0.33975561149481687), ('500061', -0.3180504047794837), ('500062', -0.29476068256576377), ('500063', -0.3063125972327742), ('500064', -0.3070384646677894), ('500065', -0.298929994296156), ('500066', -0.32734504876443465), ('500067', -0.323848492217715), ('500068', -0.32313147682459026), ('500069', -0.2892901206774783), ('500070', -0.35011250050661935), ('500071', -0.3026921120995886), ('500072', -0.3019750967064638), ('500073', -0.31687308320805657), ('500074', -0.31692619545939915), ('500075', -0.3547598224990948), ('500076', -0.3305406358868797), ('500077', -0.33351492196206406), ('500078', -0.3205643846763657), ('500079', -0.3346125751564773), ('500080', -0.33495780479020404), ('500081', -0.2873072632940221), ('500082', -0.30293996927252054), ('500083', -0.3245832116946207), ('500084', -0.32020145095885805), ('500085', -0.29677009607489124), ('500086', -0.3133234144099944), ('500087', -0.3202899713777624), ('500088', -0.33586071306302784), ('500089', -0.2964956827762879), ('500090', -0.301753795659203), ('500091', -0.33226678405551346), ('500092', -0.3260703547322128), ('500093', -0.3357987487697948), ('500094', -0.32117517556680536), ('500095', -0.31842219053888177), ('500096', -0.28851114099112046), ('500097', -0.3008243312607079), ('500098', -0.33426734552275056), ('500099', -0.32321999724349454), ('500100', 3.216561070027123), ('500101', 3.1347947590852256), ('500102', 3.298398197304144), ('500103', 3.212798952223691), ('500104', 3.0683601846975526), ('500105', 3.157907440461137), ('500106', 3.0512757438490232), ('500107', 3.2419044659594225), ('500108', 3.124012972062683), ('500109', 3.103777204301161)]
# compute_location_frequency 0.0009090909090909091
# find_outliers [{'user_id': '21', 'transaction_id': '500100', 'description': 'HOTEL PLEASURE', 'amount': 4042.34, 'x_coordinate': 189.0, 'y_coordinate': 81.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500101', 'description': 'CAFE QWERTY', 'amount': 3949.97, 'x_coordinate': 68.0, 'y_coordinate': 154.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500102', 'description': 'whole flash', 'amount': 4134.79, 'x_coordinate': 191.0, 'y_coordinate': 96.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500103', 'description': 'AMAZON.TW', 'amount': 4038.09, 'x_coordinate': 163.0, 'y_coordinate': 131.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500104', 'description': 'USAIRWAY', 'amount': 3874.92, 'x_coordinate': 173.0, 'y_coordinate': 51.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500105', 'description': 'HOTEL PLEASURE', 'amount': 3976.08, 'x_coordinate': 133.0, 'y_coordinate': 191.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500106', 'description': 'coffee YYY', 'amount': 3855.62, 'x_coordinate': 91.0, 'y_coordinate': 127.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500107', 'description': 'CANADIAN PHARMACY', 'amount': 4070.97, 'x_coordinate': 144.0, 'y_coordinate': 126.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500108', 'description': 'CIKUIT CITY', 'amount': 3937.79, 'x_coordinate': 184.0, 'y_coordinate': 57.0, 'is_fraudulent': True}, {'user_id': '21', 'transaction_id': '500109', 'description': 'CAFE QWERTY', 'amount': 3914.93, 'x_coordinate': 199.0, 'y_coordinate': 121.0, 'is_fraudulent': True}]
# compute_percentiles {0.25: 38.4225, 0.5: 54.745, 0.75: 72.09}
